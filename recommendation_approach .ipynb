# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import KFold

# %%
df=pd.read_csv('clean_swiggy_data.csv',encoding='latin1')

# %%
df.head()
# Out:
#           restaurant_name  ratings                                cuisines  \
# 0                     kfc      4.4       burgers, fast food, rolls & wraps
# 1               pizza hut      4.3                                  pizzas
# 2                  subway      4.4         healthy food, salads, fast food
# 3              mcdonald's      4.4      burgers, beverages, cafe, desserts
# 4  the belgian waffle co.      4.6  waffle, desserts, ice cream, beverages
#
#    pricing             address  distance   city  pricing_impute
# 0     80.0  vallabh vidyanagar      38.0  anand              80
# 1    189.0             hadgood      42.0  anand             189
# 2      NaN       mahadev nagar      32.0  anand             100
# 3    179.0  vallabh vidyanagar      32.0  anand             179
# 4      NaN      triveni arcade      38.0  anand              49

# %%
df=df.drop(columns='pricing',axis=1)

# %%
df['ratings']=df['ratings'].round(1)
df['distance']=df['distance'].round(2)

# %%
df
# Out:
#                             restaurant_name  ratings  \
# 0                                       kfc      4.4
# 1                                 pizza hut      4.3
# 2                                    subway      4.4
# 3                                mcdonald's      4.4
# 4                    the belgian waffle co.      4.6
# ...                                     ...      ...
# 4145                   ganga gayatri samosa      4.3
# 4146         bombay chopati bhelpuri center      4.4
# 4147  janta paubhaji pulav ice cream center      4.0
# 4148                                bao box      4.2
# 4149                      celebration foods      4.4
#
#                                     cuisines             address  distance  \
# 0          burgers, fast food, rolls & wraps  vallabh vidyanagar      38.0
# 1                                     pizzas             hadgood      42.0
# 2            healthy food, salads, fast food       mahadev nagar      32.0
# 3         burgers, beverages, cafe, desserts  vallabh vidyanagar      32.0
# 4     waffle, desserts, ice cream, beverages      triveni arcade      38.0
# ...                                      ...                 ...       ...
# 4145          fast food, street food, snacks           bus stand      38.0
# 4146                           chaat, snacks             nadiyad      38.0
# 4147                                  indian             nadiyad      47.0
# 4148                  chinese, indian, asian             nadiyad      45.6
# 4149                    beverages, fast food             nadiyad      49.6
#
#          city  pricing_impute
# 0       anand              80
# 1       anand             189
# 2       anand             100
# 3       anand             179
# 4       anand              49
# ...       ...             ...
# 4145  nadiyad              40
# 4146  nadiyad              40
# 4147  nadiyad              80
# 4148  nadiyad             100
# 4149  nadiyad              40
#
# [4150 rows x 7 columns]

# %%
df[df.duplicated()]
# Out:
#                                       restaurant_name  ratings  \
# 21                                    vadilal hangout      4.7
# 25                                      grameen kulfi      4.6
# 27                                   jassi de parathe      4.6
# 28                                          taco bell      4.3
# 29                                   starbucks coffee      4.4
# 30                                    cafe coffee day      4.5
# 31                                    la pino'z pizza      4.3
# 32          gourmet ice cream cakes by baskin robbins      4.8
# 34                                     barista coffee      5.0
# 232                                    domino's pizza      4.2
# 233                                        mcdonald's      4.5
# 234                           anmol catering & events      4.3
# 235                      kishan punjabi chhole kulche      4.6
# 238                                               kfc      4.3
# 240                          shree kismat kathiyawadi      4.2
# 886                                               kfc      4.3
# 889                                     grameen kulfi      4.8
# 900                     the westend hotel (mayflower)      4.6
# 906                                the belgian waffle      4.1
# 918                                    nic ice creams      4.6
# 919   kwality walls frozen dessert and ice cream shop      4.6
# 920                            the belgian waffle co.      4.6
# 921                  faasos - wraps, rolls & shawarma      4.4
# 924                                     huber & holly      4.3
# 2442                                london yard pizza      4.2
# 2445                                 mayur restaurant      4.2
# 2449                       shakti - the sandwich shop      4.2
# 2450             mcdonald's gourmet burger collection      4.5
# 2452                                       mcdonald's      4.5
# 2453                                  la pino'z pizza      4.5
# 4084                              pastas by pizza hut      3.3
# 4087                                 delights by inox      4.1
# 4088             mcdonald's gourmet burger collection      4.8
# 4091                              lotus bistro lounge      4.3
# 4093                             new india restaurant      4.4
# 4094                                       yummy time      4.3
# 4096                               deepu omlet center      4.5
# 4098                                         foodland      4.0
# 4105                                       ten eleven      4.3
# 4106                                 tummy times cafe      4.2
#
#                                                cuisines               address  \
# 21                                            ice cream              karamsad
# 25                                  ice cream, desserts    vallabh vidyanagar
# 27                          north indian, snacks, chaat    vallabh vidyanagar
# 28                           mexican, fast food, snacks          sojitra road
# 29    beverages, cafe, snacks, desserts, bakery, ice...    anand sojitra road
# 30    beverages, cafe, snacks, desserts, burgers, ic...    vallabh vidyanagar
# 31         pizzas, pastas, italian, desserts, beverages  maruti solaris annex
# 32         ice cream cakes, desserts, ice cream, bakery    vallabh vidyanagar
# 34    beverages, fast food, snacks, biryani, pastas,...          shah heights
# 232                   pizzas, italian, pastas, desserts             fatehgunj
# 233                  burgers, beverages, cafe, desserts             fatehgunj
# 234             north indian, biryani, chinese, punjabi         sardar estate
# 235                    north indian, punjabi, fast food      amrapali complex
# 238                   burgers, fast food, rolls & wraps              alkapuri
# 240                        gujarati, thalis, rajasthani             fatehgunj
# 886                   burgers, fast food, rolls & wraps      paldi & ambawadi
# 889                                 ice cream, desserts             maninagar
# 900                                     indian, chinese          ellis bridge
# 906                            desserts, snacks, bakery             maninagar
# 918                                 ice cream, desserts             maninagar
# 919                desserts, ice cream, ice cream cakes           navrangpura
# 920              waffle, desserts, ice cream, beverages             maninagar
# 921   kebabs, fast food, snacks, american, healthy f...             maninagar
# 924                                 desserts, ice cream             maninagar
# 2442                           pizzas, pastas, desserts        radhanpur road
# 2445      biryani, chinese, snacks, desserts, beverages               mehsana
# 2449                 pizzas, burgers, snacks, beverages              nagalpur
# 2450                 burgers, beverages, cafe, desserts               mehsana
# 2452                 burgers, beverages, cafe, desserts               mehsana
# 2453  pizzas, pastas, beverages, fast food, italian,...               mehsana
# 4084                                             pastas          shanti nagar
# 4087                                             snacks               nadiyad
# 4088                 burgers, beverages, cafe, desserts          shanti nagar
# 4091  fast food, biryani, mexican, pizzas, italian, ...           petlad road
# 4093               biryani, mughlai, chinese, fast food      nagarpalika road
# 4094     burgers, fast food, pizzas, mexican, beverages              pij road
# 4096                          indian, snacks, fast food        kamda crossing
# 4098     burgers, fast food, pizzas, mexican, beverages              pij road
# 4105                chinese, punjabi, fast food, thalis          college road
# 4106     burgers, fast food, pizzas, mexican, beverages              pij road
#
#       distance       city  pricing_impute
# 21        28.0      anand              80
# 25        28.0      anand             120
# 27        32.0      anand              40
# 28        38.0      anand              80
# 29        38.0      anand             100
# 30        32.0      anand             100
# 31        42.0      anand             120
# 32        38.0      anand              80
# 34        38.0      anand             129
# 232       22.0   vadodara             100
# 233       28.0   vadodara             209
# 234       28.0   vadodara             120
# 235       18.0   vadodara              99
# 238       28.0   vadodara              80
# 240       18.0   vadodara              75
# 886       22.0  ahmedabad              80
# 889       18.0  ahmedabad              99
# 900       22.0  ahmedabad             120
# 906       28.0  ahmedabad             150
# 918       18.0  ahmedabad             179
# 919       28.0  ahmedabad              90
# 920       38.0  ahmedabad              75
# 921       38.0  ahmedabad             100
# 924       28.0  ahmedabad              40
# 2442      28.0    mehsana              80
# 2445      28.0    mehsana             120
# 2449      28.0    mehsana             120
# 2450      22.0    mehsana              80
# 2452      22.0    mehsana              75
# 2453      22.0    mehsana             199
# 4084      52.0    nadiyad              80
# 4087      48.0    nadiyad             120
# 4088      42.0    nadiyad              80
# 4091      52.0    nadiyad             120
# 4093      42.0    nadiyad             119
# 4094      38.0    nadiyad              59
# 4096      48.0    nadiyad              99
# 4098      32.0    nadiyad              59
# 4105      48.0    nadiyad              89
# 4106      48.0    nadiyad              59

# %%
df[(df['restaurant_name']=='grameen kulfi') & (df['city']=='anand')]
# Out:
#    restaurant_name  ratings             cuisines             address  \
# 12   grameen kulfi      4.6  ice cream, desserts  vallabh vidyanagar
# 25   grameen kulfi      4.6  ice cream, desserts  vallabh vidyanagar
#
#     distance   city  pricing_impute
# 12      28.0  anand             120
# 25      28.0  anand             120

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (4110, 7)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[(df['restaurant_name']=="al - shahi") & (df['city']=='mehsana')]
# Out:
#      restaurant_name  ratings          cuisines  address  distance     city  \
# 2434      al - shahi      4.0  mughlai, biryani  mehsana      22.0  mehsana
# 2454      al - shahi      4.0  mughlai, biryani  mehsana      22.0  mehsana
#
#       pricing_impute
# 2434              50
# 2454             100

# %%
df = df.drop_duplicates(subset=['restaurant_name', 'ratings', 'cuisines', 'address', 'distance', 'city'],keep='last')

# %%
df[(df['restaurant_name']=="al - shahi") & (df['city']=='mehsana')]
# Out:
#      restaurant_name  ratings          cuisines  address  distance     city  \
# 2454      al - shahi      4.0  mughlai, biryani  mehsana      22.0  mehsana
#
#       pricing_impute
# 2454             100

# %%
dfc=df.copy()

# %%
dfc.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4145    False
# 4146    False
# 4147    False
# 4148    False
# 4149    False
# Length: 4092, dtype: bool

# %%
dfc['cuisines']
# Out:
# 0            burgers, fast food, rolls & wraps
# 1                                       pizzas
# 2              healthy food, salads, fast food
# 3           burgers, beverages, cafe, desserts
# 4       waffle, desserts, ice cream, beverages
#                          ...
# 4145            fast food, street food, snacks
# 4146                             chaat, snacks
# 4147                                    indian
# 4148                    chinese, indian, asian
# 4149                      beverages, fast food
# Name: cuisines, Length: 4092, dtype: object

# %%
import re
# remove the punctuation except commas
dfc['cuisines'] = dfc['cuisines'].apply(lambda x: re.sub(r'[^\w\s,]', '', x) if isinstance(x, str) else x)

# %%
dfc['cuisines']
# Out:
# 0             burgers, fast food, rolls  wraps
# 1                                       pizzas
# 2              healthy food, salads, fast food
# 3           burgers, beverages, cafe, desserts
# 4       waffle, desserts, ice cream, beverages
#                          ...
# 4145            fast food, street food, snacks
# 4146                             chaat, snacks
# 4147                                    indian
# 4148                    chinese, indian, asian
# 4149                      beverages, fast food
# Name: cuisines, Length: 4092, dtype: object

# %%
def remove_space(text):
    # Splitting by comma to separate different cuisines
    cuisines = re.split(r'\s*,\s*', text)
    # Removing extra spaces and special characters, then joining words within each cuisine
    cleaned_cuisines = []
    for cuisine in cuisines:
        cleaned_cuisine = re.sub(r'\s+', '', cuisine) if len(cuisine.split()) > 1 else cuisine
        # this split the each word fast food as 'fast', 'food' then it check if word is > 1 means (fast,food) 2 words so >1 
        # then it will remove the space otherwise returns the as it is 
        cleaned_cuisines.append(cleaned_cuisine)
    # Joining the cleaned cuisines back together
    return ', '.join(cleaned_cuisines)

# %%
dfc['cuisines'] = dfc['cuisines'].apply(remove_space)

# %%
dfc['cuisines']
# Out:
# 0               burgers, fastfood, rollswraps
# 1                                      pizzas
# 2               healthyfood, salads, fastfood
# 3          burgers, beverages, cafe, desserts
# 4       waffle, desserts, icecream, beverages
#                         ...
# 4145             fastfood, streetfood, snacks
# 4146                            chaat, snacks
# 4147                                   indian
# 4148                   chinese, indian, asian
# 4149                      beverages, fastfood
# Name: cuisines, Length: 4092, dtype: object

# %%
dfc['city'].value_counts()
# Out:
# city
# gandhinagar    1554
# ahmedabad      1543
# vadodara        642
# anand           200
# nadiyad          80
# mehsana          73
# Name: count, dtype: int64

# %%
def recommedations(city,cuisines_weight=0.5,ratings_weight=0.3,distance_weight=0.2):
    df_city=dfc[dfc['city']==city]
    
    scaler = MinMaxScaler()
    #scaler=StandardScaler()
    df_city.loc[:,['ratings','distance']]=scaler.fit_transform(df_city[['ratings','distance']])
    
    tfidf=TfidfVectorizer()
    cuisine_metric=tfidf.fit_transform(df_city['cuisines'])
    
    rating_similarity=cosine_similarity(df_city[['ratings']],df_city[['ratings']])
    #print('before: ',df['ratings'].var())
    #print('after : ',df_city['ratings'].var())
    # var() is low so closer values that means ones metric
    distance_similarity=cosine_similarity(df_city[['distance']],df_city[['distance']])
     # Adjust distance similarity for self-comparisons
    np.fill_diagonal(distance_similarity, 1.0)
    cuisine_similarity=cosine_similarity(cuisine_metric,cuisine_metric)
    
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                                ratings_weight * rating_similarity +
                                distance_weight * distance_similarity)
    
    #print("Rating Similarity:\n", rating_similarity)
    #print("Distance Similarity:\n", distance_similarity)
    #print("Cuisine Similarity:\n", cuisine_similarity)
    #print('weighted_similarity:\n',weighted_similarity)

    
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    return similarity_df
    
    
  
    #print(city_combined_similarity)

# %%
sm=recommedations(city='mehsana')

# %%
sm.head(10)
# Out:
# restaurant_name             navjivan restaurant  real paprika  \
# restaurant_name
# navjivan restaurant                    1.000000      0.453117
# real paprika                           0.453117      1.000000
# neelkanth restaurant                   0.800000      0.653117
# hotel tulsi                            0.496750      0.675020
# krishna restaurant                     0.649461      0.719076
# london yard pizza                      0.300000      0.832678
# sankalp restaurant                     0.378448      0.697819
# sam's pizza                            0.300000      0.730736
# mayur restaurant                       0.686401      0.700012
# shakti - the sandwich shop             0.381747      0.609750
#
# restaurant_name             neelkanth restaurant  hotel tulsi  \
# restaurant_name
# navjivan restaurant                     0.800000     0.496750
# real paprika                            0.653117     0.675020
# neelkanth restaurant                    1.000000     0.696750
# hotel tulsi                             0.696750     1.000000
# krishna restaurant                      0.849461     0.781505
# london yard pizza                       0.500000     0.577670
# sankalp restaurant                      0.578448     0.841386
# sam's pizza                             0.500000     0.611986
# mayur restaurant                        0.886401     0.652049
# shakti - the sandwich shop              0.581747     0.641025
#
# restaurant_name             krishna restaurant  london yard pizza  \
# restaurant_name
# navjivan restaurant                   0.649461           0.300000
# real paprika                          0.719076           0.832678
# neelkanth restaurant                  0.849461           0.500000
# hotel tulsi                           0.781505           0.577670
# krishna restaurant                    1.000000           0.500000
# london yard pizza                     0.500000           1.000000
# sankalp restaurant                    0.612242           0.723400
# sam's pizza                           0.500000           0.846787
# mayur restaurant                      0.770065           0.622766
# shakti - the sandwich shop            0.616961           0.587928
#
# restaurant_name             sankalp restaurant  sam's pizza  mayur restaurant  \
# restaurant_name
# navjivan restaurant                   0.378448     0.300000          0.686401
# real paprika                          0.697819     0.730736          0.700012
# neelkanth restaurant                  0.578448     0.500000          0.886401
# hotel tulsi                           0.841386     0.611986          0.652049
# krishna restaurant                    0.612242     0.500000          0.770065
# london yard pizza                     0.723400     0.846787          0.622766
# sankalp restaurant                    1.000000     0.822100          0.674651
# sam's pizza                           0.822100     1.000000          0.677004
# mayur restaurant                      0.674651     0.677004          1.000000
# shakti - the sandwich shop            0.653207     0.626775          0.681995
#
# restaurant_name             shakti - the sandwich shop  ...  \
# restaurant_name                                         ...
# navjivan restaurant                           0.381747  ...
# real paprika                                  0.609750  ...
# neelkanth restaurant                          0.581747  ...
# hotel tulsi                                   0.641025  ...
# krishna restaurant                            0.616961  ...
# london yard pizza                             0.587928  ...
# sankalp restaurant                            0.653207  ...
# sam's pizza                                   0.626775  ...
# mayur restaurant                              0.681995  ...
# shakti - the sandwich shop                    1.000000  ...
#
# restaurant_name             jay ambe restaurant  navdurga bhajipav  \
# restaurant_name
# navjivan restaurant                    0.752967           0.300000
# real paprika                           0.606984           0.500000
# neelkanth restaurant                   0.952967           0.500000
# hotel tulsi                            0.637471           0.585165
# krishna restaurant                     0.744172           0.500000
# london yard pizza                      0.500000           0.500000
# sankalp restaurant                     0.500000           0.500000
# sam's pizza                            0.500000           0.500000
# mayur restaurant                       0.850054           0.500000
# shakti - the sandwich shop             0.500000           0.500000
#
# restaurant_name             sejan chinese & punjabi  pariwar restaurant  \
# restaurant_name
# navjivan restaurant                        0.432446            0.367174
# real paprika                               0.637989            0.542111
# neelkanth restaurant                       0.632446            0.567174
# hotel tulsi                                0.677311            0.633590
# krishna restaurant                         0.689500            0.596111
# london yard pizza                          0.582601            0.500000
# sankalp restaurant                         0.576721            0.558786
# sam's pizza                                0.619095            0.500000
# mayur restaurant                           0.713977            0.551912
# shakti - the sandwich shop                 0.711663            0.561257
#
# restaurant_name             health point fruit & juice bar  bansi kathiyawadi  \
# restaurant_name
# navjivan restaurant                               0.371145                0.3
# real paprika                                      0.544600                0.5
# neelkanth restaurant                              0.571145                0.5
# hotel tulsi                                       0.557310                0.5
# krishna restaurant                                0.601792                0.5
# london yard pizza                                 0.500000                0.5
# sankalp restaurant                                0.562260                0.5
# sam's pizza                                       0.500000                0.5
# mayur restaurant                                  0.658391                0.5
# shakti - the sandwich shop                        0.686904                0.5
#
# restaurant_name             rudra fastfood & punjabi  vicky fry centre  \
# restaurant_name
# navjivan restaurant                         0.428682          0.300000
# real paprika                                0.634068          0.500000
# neelkanth restaurant                        0.628682          0.500000
# hotel tulsi                                 0.672273          0.605511
# krishna restaurant                          0.684115          0.500000
# london yard pizza                           0.580254          0.500000
# sankalp restaurant                          0.574541          0.500000
# sam's pizza                                 0.615711          0.500000
# mayur restaurant                            0.599446          0.500000
# shakti - the sandwich shop                  0.577675          0.500000
#
# restaurant_name             bhavika restaurant  \
# restaurant_name
# navjivan restaurant                   0.468947
# real paprika                          0.605912
# neelkanth restaurant                  0.668947
# hotel tulsi                           0.709458
# krishna restaurant                    0.741725
# london yard pizza                     0.500000
# sankalp restaurant                    0.554263
# sam's pizza                           0.500000
# mayur restaurant                      0.630563
# shakti - the sandwich shop            0.556545
#
# restaurant_name             the chai theka specialist of chai
# restaurant_name
# navjivan restaurant                                  0.355267
# real paprika                                         0.534647
# neelkanth restaurant                                 0.555267
# hotel tulsi                                          0.544520
# krishna restaurant                                   0.579075
# london yard pizza                                    0.500000
# sankalp restaurant                                   0.548366
# sam's pizza                                          0.500000
# mayur restaurant                                     0.623043
# shakti - the sandwich shop                           0.645193
#
# [10 rows x 73 columns]

# %%
sm['navjivan restaurant']
# Out:
# restaurant_name
# navjivan restaurant                  1.000000
# real paprika                         0.453117
# neelkanth restaurant                 0.800000
# hotel tulsi                          0.496750
# krishna restaurant                   0.649461
#                                        ...
# bansi kathiyawadi                    0.300000
# rudra fastfood & punjabi             0.428682
# vicky fry centre                     0.300000
# bhavika restaurant                   0.468947
# the chai theka specialist of chai    0.355267
# Name: navjivan restaurant, Length: 73, dtype: float64

# %%
dfc[(dfc['restaurant_name']=='navjivan restaurant') & (dfc['city']=='mehsana')]
# Out:
#           restaurant_name  ratings                     cuisines  \
# 2418  navjivan restaurant      4.4  chinese, biryani, beverages
#
#                     address  distance     city  pricing_impute
# 2418  radhakrishna township      18.0  mehsana              80

# %%
dfc[(dfc['restaurant_name']=='tasty meals restaurant & banquet') & (dfc['city']=='ahmedabad')]
# Out:
#                        restaurant_name  ratings  \
# 2415  tasty meals restaurant & banquet      4.2
#
#                                                cuisines address  distance  \
# 2415  indian, chinese, thai, mexican, continental, p...  naroda      31.6
#
#            city  pricing_impute
# 2415  ahmedabad             120

# %%
dfc[(dfc['restaurant_name']=="sam's pizza") & (dfc['city']=='mehsana')]
# Out:
#      restaurant_name  ratings          cuisines  address  distance     city  \
# 2425     sam's pizza      4.6  pizzas, desserts  mehsana      28.0  mehsana
# 2440     sam's pizza      4.6            pizzas  mehsana      28.0  mehsana
#
#       pricing_impute
# 2425              40
# 2440             115

# %%
dfc[(dfc['restaurant_name']=="gj 25 china town restaurant") & (dfc['city']=='ahmedabad')].index[0]
# Out:
# 2416

# %%
dfc = dfc.groupby(['restaurant_name', 'ratings', 'address', 'distance', 'city'], as_index=False).agg({
    'cuisines': lambda x: ', '.join(sorted(set(x))),
    'pricing_impute': 'mean'  # or any other aggregation you want for numeric columns
     })

# %%
def r(city, user_cuisines=None, num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2):
    
    
    df_city = dfc[dfc['city'] == city]
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city.loc[:,['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
     # If user_cuisines are provided, ensure they exist in the dataset
    if user_cuisines:
        available_cuisines = df_city['cuisines'].str.lower().unique()
        user_cuisines_lower = [c.lower() for c in user_cuisines]
        
        # Check if any of the requested cuisines exist in the dataset
        if not any(cuisine in ', '.join(available_cuisines) for cuisine in user_cuisines_lower):
            return f"No restaurants offering the requested cuisines: {', '.join(user_cuisines)}."
        
    
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity +
                           distance_weight * distance_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
    
    return top_recommendations_overall


# r(city='mehsana', user_cuisines=['chinese'])

# %%
r(city='mehsana',user_cuisines=['Pizzas'])
# Out:
# ['jay ambe fast food',
#  'hungritos',
#  '7 heart pizzeria',
#  'london wraps',
#  'zorko brand of food lovers']

# %%
recommendations = r(city='mehsana', user_cuisines=['chinese', 'italian'])
unique_cuisines = dfc[dfc['restaurant_name'].isin(recommendations)]['cuisines'].unique()
print("Unique cuisines in recommendations:", unique_cuisines)

# Ensure diversity of cuisines is respected
assert len(unique_cuisines) > 1, "Recommendations are not diverse!"
# Out:
# Unique cuisines in recommendations: ['chinese, punjabi, beverages, snacks, pizzas, fastfood'
#  'southindian, chinese, fastfood, pizzas, beverages' 'chinese, beverages'
#  'biryani, chinese, snacks, desserts, beverages'
#  'chinese, biryani, beverages']

# %%
# Test with an unknown cuisine
#recommendations = r(city='mehsana', user_cuisines=['exotic'])
#print("Recommendations for unknown cuisine:", recommendations)

# Test with a city that has few or no restaurants
recommendations = r(city='mehsana', user_cuisines=['chaat'])
print("Recommendations for an unknown city:", recommendations)
# Out:
# Recommendations for an unknown city: ['brothers cafe', "mcdonald's", "mcdonald's gourmet burger collection", "bhukhkhad's cafe", 'food costa']

# %%
dfc[(dfc['restaurant_name']=="mcdonald's gourmet burger collection") & (dfc['city']=='mehsana')][['restaurant_name','ratings','address','distance','city','cuisines','pricing_impute']]
# Out:
#                            restaurant_name  ratings  address  distance  \
# 2133  mcdonald's gourmet burger collection      4.5  mehsana      22.0
#
#          city                            cuisines  pricing_impute
# 2133  mehsana  burgers, beverages, cafe, desserts            80.0

# %%
dfc.shape
# Out:
# (4091, 7)

# %%
dfc.duplicated().sum()
# Out:
# 0

# %%
#dfc.to_excel("C:\\Users\\Dell\\Downloads\\final_web_data_swiggy.xlsx",index=False)

# %%
dfc['city'].value_counts()
# Out:
# city
# gandhinagar    1554
# ahmedabad      1543
# vadodara        642
# anand           200
# nadiyad          80
# mehsana          72
# Name: count, dtype: int64

# %%
def r2(city, user_cuisines=None, num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.4, distance_weight=0.0):
    df_city = dfc[dfc['city'] == city]
    
    df_city['ratings_origin']=df_city['ratings']
    df_city['distance_origin']=df_city['distance']
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city.loc[:,['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity +
                           distance_weight * distance_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
     # Return a DataFrame with the top recommendations
    top_recommendations_df = df_city[df_city['restaurant_name'].isin(top_recommendations_overall)]

    return top_recommendations_df[['restaurant_name','ratings_origin','address','cuisines','distance_origin']]

    
    #return top_recommendations_overall


# r(city='mehsana', user_cuisines=['chinese'])

# %%
r2(city='mehsana',user_cuisines=['pizzas'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15600\3723402350.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['ratings_origin']=df_city['ratings']
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15600\3723402350.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['distance_origin']=df_city['distance']
#          restaurant_name  ratings_origin         address  \
# 22      7 heart pizzeria             4.2         mehsana
# 1467           hungritos             3.7         mehsana
# 1562  jay ambe fast food             4.3         mehsana
# 1949        london wraps             4.2  radhanpur road
# 2232        moment mocha             4.1         mehsana
#
#                                  cuisines  distance_origin
# 22                       pizzas, fastfood             22.0
# 1467  snacks, fastfood, beverages, pizzas             32.0
# 1562          fastfood, pizzas, beverages             22.0
# 1949                     fastfood, pizzas             28.0
# 2232  beverages, fastfood, pizzas, snacks             18.0

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler
import numpy as np

def recommend_knn(city, user_cuisines, num_neighbors=5, cuisines_weight=7, ratings_weight=2, distance_weight=1):
    # Filter the DataFrame based on city
    df_city = dfc[dfc['city'] == city]
    
    
    df_city['ratings_origin']=df_city['ratings']
    df_city['distance_origin']=df_city['distance']
    
    # Scale the features (ratings and distance)
    scaler = MinMaxScaler()
    df_city[['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    # Vectorize cuisines using TF-IDF
    tfidf = TfidfVectorizer()
    cuisine_vectors = tfidf.fit_transform(df_city['cuisines']).toarray()
    
    # Apply weights to each feature
    cuisine_vectors_weighted = cuisine_vectors * cuisines_weight
    ratings_weighted = df_city[['ratings']].values * ratings_weight
    distance_weighted = df_city[['distance']].values * distance_weight
    
    # Combine features (cuisines, ratings, distance) for KNN
    features = np.hstack([cuisine_vectors_weighted, ratings_weighted, distance_weighted])
    
    # Fit the KNN model
    knn = NearestNeighbors(n_neighbors=num_neighbors, metric='cosine')
    knn.fit(features)
    
    # Transform user input cuisines into the same TF-IDF space
    user_cuisine_vector = tfidf.transform([', '.join(user_cuisines)]).toarray()
    
    # Apply weights to the user vector for cuisines and use placeholder for ratings and distance
    user_cuisine_vector_weighted = user_cuisine_vector * cuisines_weight
    user_vector = np.hstack([user_cuisine_vector_weighted, np.array([[0.5 * ratings_weight, 0.5 * distance_weight]])])  # Placeholder for ratings and distance
    
    # Find the nearest neighbors (recommended restaurants)
    distances, indices = knn.kneighbors(user_vector)
    
    # Get the top recommended restaurants
    recommended_restaurants = df_city.iloc[indices[0]].copy()

    return recommended_restaurants[['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'distance_origin']]

# %%
recommend_knn(city='mehsana',user_cuisines=['chinese'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15600\3508367064.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['ratings_origin']=df_city['ratings']
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15600\3508367064.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['distance_origin']=df_city['distance']
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15600\3508367064.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city[['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
#            restaurant_name  ratings_origin                address  \
# 1841    krishna restaurant             4.1   suramya park society
# 1582   jay bhavani vadapav             4.2                mehsana
# 1566   jay ambe restaurant             3.9                mehsana
# 2376  neelkanth restaurant             4.5                  kunal
# 2364   navjivan restaurant             4.4  radhakrishna township
#
#                          cuisines  distance_origin
# 1841           chinese, beverages             28.0
# 1582            fastfood, chinese             22.0
# 1566             chinese, biryani             28.0
# 2376  chinese, biryani, beverages             22.0
# 2364  chinese, biryani, beverages             18.0

# %%
dfc['cuisines'].unique()
# Out:
# array(['arabian, continental, american, turkish', 'snacks, chinese',
#        'northindian, pizzas', ...,
#        'beverages, pizzas, momos, sandwich, snacks, fastfood, rollswraps, grill, pastas, mexican',
#        'beverages, pizzas, fastfood, burgers',
#        'burgers, pastas, snacks, beverages'], dtype=object)

# %%
# Assuming cuisines are already in a list format per row
unique_cuisines = dfc['cuisines'].unique()

# Print unique cuisines
print("Unique Cuisines:")
for cuisine in unique_cuisines:
    print(cuisine)
# Out:
# Unique Cuisines:
# arabian, continental, american, turkish
# snacks, chinese
# northindian, pizzas
# indian, chinese, continental, desserts, beverages
# biryani, continental, oriental, indian
# fastfood
# healthyfood, snacks, northindian, salads, sandwich
# mughlai, chinese, biryani, fastfood, desserts
# northindian, biryani, snacks
# southindian
# northindian, chaat, snacks, beverages
# pizzas, italianamerican, pastas, fastfood, cafe
# indian, northindian
# salads, mexican
# indian
# pizzas
# icecream, pizzas, fastfood, burgers, snacks, beverages
# chinese, biryani, beverages, continental
# beverages, desserts
# indian, italian, continental, northindian, chinese, beverages, snacks, fastfood
# pizzas, fastfood
# cafe, beverages, fastfood, pizzas, snacks
# bakery, waffle, icecreamcakes
# indian, burgers, jain
# pizzas, fastfood, burgers, cafe
# cafe, juices, beverages, desserts, fastfood, burgers, snacks
# juices, beverages, desserts, healthyfood
# bakery, desserts
# burgers, fastfood, snacks
# biryani
# biryani, tandoor
# chinese
# indian, tandoor, snacks, biryani
# chinese, northindian, tandoor
# biryani, hyderabadi, beverages
# biryani, pizzas
# biryani, southindian, mughlai, hyderabadi, indian, cafe
# beverages
# chinese, snacks
# snacks
# northindian, indian, punjabi
# sweets, desserts, beverages
# seafood, chinese, biryani, mughlai, tandoor
# northindian, chinese
# snacks, fastfood, pizzas, burgers
# pavbhaji, chinese, fastfood
# northindian, chinese, biryani
# northindian, punjabi, chinese
# chinese, mughlai, biryani, beverages
# biryani, gujarati, streetfood, snacks, pizzas, haleem, barbecue, homefood, fastfood, burgers
# northindian, gujarati, tandoor, biryani, beverages
# snacks, beverages
# paan
# momos, rolls
# chinese, northindian, punjabi, southindian, pizzas
# biryani, chinese, punjabi
# sweets
# mughlai, indian, fastfood
# pizzas, chinese
# fastfood, burgers, chinese, snacks, pastas
# beverages, juices
# northindian, thalis, mughlai, beverages, desserts, punjabi, kebabs
# italian, beverages, salads, pizzas
# burgers
# fastfood, cafe
# mughlai, biryani
# arabian, grill, pizzas, seafood, tandoor
# shawarma, arabian, beverages, tandoor, burgers
# chinese, seafood
# northindian, mughlai
# arabian
# indian, mughlai, afghani
# american, middleeastern, lebanese, arabian, beverages, pizzas, barbecue, fastfood, burgers
# pastas, burgers, pizzas
# indian, chinese, continental, italian, mexican
# chinese, fastfood, burgers
# biryani, mughlai, beverages
# salads, healthyfood
# indian, chinese
# homefood, cafe
# fastfood, pizzas
# chinese, southindian, burgers, icecream, pizzas, biryani
# beverages, southindian, sweets
# biryani, northindian, snacks
# biryani, northindian, tandoor, desserts, beverages
# indian, northindian, snacks
# biryani, punjabi, tandoor, thalis, beverages
# icecream
# homefood
# streetfood, indian
# juices
# indian, chinese, continental, southindian
# southindian, fastfood, cafe
# southindian, chinese, continental, pizzas, tandoor, fastfood, northindian, beverages, snacks
# gujarati
# gujarati, punjabi
# thalis, northindian, punjabi, chinese, biryani
# northindian, streetfood, tandoor, indian
# indian, beverages
# northindian, mughlai, tandoor, chinese, biryani
# punjabi, beverages
# pizzas, beverages, oriental, fastfood, southindian
# icecream, desserts
# southindian, chinese, streetfood, fastfood, snacks
# fastfood, southindian, chinese, snacks
# northindian
# beverages, fastfood
# desserts, icecream
# desserts, icecream, snacks
# desserts, indian, sweets
# indian, snacks, fastfood
# jain, burgers
# northindian, biryani, chinese, punjabi
# southindian, indian, beverages
# fastfood, beverages
# sweets, indian, gujarati, fastfood, snacks
# maharashtrian, homefood, healthyfood, navratrispecial
# fastfood, snacks, burgers
# fastfood, southindian, beverages
# chinese, fastfood
# tandoor, barbecue
# northindian, barbecue
# burgers, beverages, snacks
# juices, beverages, desserts
# healthyfood, juices, beverages, desserts
# punjabi, northindian
# punjabi
# afghani, fastfood
# pizzas, snacks, beverages
# chinese, tandoor
# pizzas, italian, fastfood, american, desserts
# snacks, pizzas, beverages
# arabian, chinese
# pizzas, snacks, burgers
# indian, lebanese
# jain, streetfood, snacks, italianamerican, healthyfood, navratrispecial, icecreamcakes, fastfood, burgers, cafe
# indian, snacks
# northindian, indian
# indian, chinese, kebabs, biryani
# northindian, continental
# northindian, mughlai, chinese, seafood, kebabs, biryani
# beverages, icecream, juices
# italian, pizzas, sandwich, burgers, rollswraps, snacks, beverages
# bakery
# burgers, pizzas, pastas, chinese
# indian, chaat, snacks
# pizzas, northindian, chinese
# desserts
# desserts, beverages
# indian, thalis, northindian, punjabi, chinese, continental, snacks, pizzas
# paan, desserts
# northindian, snacks, sweets
# thalis
# northindian, continental, punjabi, biryani, chinese, indian, mexican
# northindian, indian, chinese, fastfood, snacks, beverages
# fastfood, pizzas, snacks
# fastfood, burgers, american, continental, pizzas, indian, snacks
# burgers, snacks
# desserts, fastfood
# cafe, fastfood, italian, chinese, northindian, icecream, snacks, beverages
# beverages, snacks
# cafe
# fastfood, burgers, cafe
# northindian, chinese, punjabi, gujarati
# mughlai
# chinese, streetfood, fastfood
# icecream, icecreamcakes, fastfood, cafe
# streetfood, pizzas, fastfood
# chinese, biryani, afghani, mughlai, seafood, tandoor
# fastfood, chinese
# gujarati, snacks, rolls, pastas
# desserts, sweets, bakery
# pizzas, indian, italian
# bakery, desserts, snacks
# fastfood, streetfood
# fastfood, italian, beverages
# southindian, chinese
# punjabi, rajasthani, gujarati
# northindian, chinese, pizzas, fastfood, biryani, beverages
# northindian, snacks, fastfood, chinese
# gujarati, snacks
# maharashtrian, fastfood, chinese, southindian
# northindian, rajasthani, biryani
# indian, hyderabadi
# chinese, indian, asian
# barbecue, biryani, kebabs, mughlai, desserts
# beverages, snacks, desserts
# beverages, fastfood, snacks, biryani, pastas, desserts
# burgers, pizzas
# beverages, cafe, pizzas, chinese
# snacks, indian, beverages
# thalis, gujarati, punjabi, jain
# punjabi, biryani
# biryani, northindian, indian, chinese, mughlai
# northindian, beverages, indian
# italian, fastfood, chinese, burgers, beverages
# snacks, homefood
# biryani, northindian, kebabs, mughlai, beverages, desserts
# chinese, asian, desserts, beverages
# snacks, desserts
# italian, pizzas, desserts
# beverages, waffle, desserts
# fastfood, snacks, italian, beverages
# desserts, indian, beverages, icecream, streetfood, snacks, pizzas, burgers, cafe
# snacks, momos, pastas, waffle, beverages
# snacks, gujarati
# juices, beverages
# indian, chaat
# indian, fastfood
# southindian, fastfood, streetfood
# northindian, italian, chinese, fastfood
# snacks, sweets
# streetfood, snacks, pizzas
# italian, italianamerican, fastfood, burgers, cafe
# chinese, punjabi, beverages, fastfood, gujarati
# snacks, sweets, gujarati
# pizzas, fastfood, chinese
# sandwich, snacks, burgers, pizzas, beverages
# chaat, snacks
# streetfood, snacks
# punjabi, thalis, gujarati, fastfood, cafe
# streetfood, fastfood, burgers
# thalis, southindian, pizzas
# tandoor, kebabs, beverages
# indian, snacks, kebabs
# desserts, beverages, salads, snacks, pizzas, pastas, fastfood, burgers, cafe
# snacks, maharashtrian
# indian, desserts
# northindian, chinese, indian
# burgers, snacks, fastfood
# burgers, snacks, pizzas
# pizzas, fastfood, beverages, burgers, snacks
# pizzas, snacks, chaat
# northindian, chinese, tibetan, desserts
# burgers, fastfood, beverages, snacks
# pizzas, chinese, snacks, fastfood, beverages, desserts
# fastfood, american, chinese, beverages
# beverages, icecream
# bihari, homefood
# pizzas, fastfood, desserts, snacks
# fastfood, snacks
# mexican, chinese, northindian, continental, italian, pizzas, fastfood
# mexican, chinese, northindian, italian, continental, pizzas, fastfood
# biryani, indian, northindian
# biryani, kebabs, desserts
# biryani, beverages
# biryani, hyderabadi, northindian
# biryani, indian, snacks
# northindian, biryani
# icecream, desserts, juices, beverages
# chinese, arabian, barbecue
# beverages, pizzas, fastfood, burgers, cafe, snacks, momos, mexican, waffle, desserts
# desserts, european, fastfood, cafe
# snacks, indian, chinese
# northindian, snacks
# american, cafe
# italian, indian, beverages, salads, fastfood
# pizzas, waffle, burgers, cafe
# bakery, snacks
# cafe, bakery
# bakery, desserts, beverages, snacks
# thalis, northindian, chaat, biryani, snacks, beverages
# northindian, kebabs, biryani, chinese, continental, beverages
# fastfood, pizzas, desserts
# fastfood, northindian, pastas
# chinese, pastas, northindian
# punjabi, northindian, southindian, biryani
# snacks, streetfood
# tandoor, chinese, biryani
# biryani, mughlai, arabian, beverages
# biryani, fastfood
# fastfood, italian, american, pizzas, burgers
# streetfood, beverages
# chinese, southindian, snacks, pizzas, fastfood
# southindian, fastfood, streetfood, pizzas
# maharashtrian, snacks, italian, fastfood, chaat
# snacks, fastfood
# maharashtrian, fastfood, southindian, snacks
# indian, fastfood, southindian, chinese
# punjabi, italian, mexican, chinese
# bengali, biryani, tandoor
# burgers, american, fastfood, snacks
# indian, chinese, homefood, healthyfood
# punjabi, chinese, pastas, indian, salads, mexican
# mexican, continental, asian
# bakery, cafe
# desserts, burgers, bakery
# indian, chinese, continental
# continental, beverages
# indian, chinese, continental, northindian, biryani, punjabi, thalis, tandoor, pastas, snacks, beverages, streetfood
# chaat, burgers, cafe, pizzas
# burgers, rollswraps, snacks, pastas
# burgers, streetfood, fastfood, beverages
# desserts, beverages, bakery
# bakery, desserts, waffle, beverages
# bakery, beverages
# streetfood, fastfood, beverages, snacks, pizzas
# fastfood, burgers, snacks
# biryani, northindian, tandoor
# burgers, snacks, beverages, continental, american, european, panasian, cafe, fastfood
# burgers, beverages, fastfood, snacks
# burgers, beverages, snacks, desserts
# american
# burgers, american, salads, beverages, chaat
# burgers, american
# fastfood, burgers
# burgers, fastfood, snacks, beverages
# burgers, snacks, beverages
# burgers, snacks, fastfood, indian, american, beverages, desserts
# burgers, snacks, desserts, beverages, fastfood, american, indian, biryani
# burgers, desserts, fastfood
# burgers, fastfood, beverages
# burgers, pizzas, beverages, healthyfood
# indian, chinese, northindian, biryani, punjabi, panasian, mughlai, thalis, asian, beverages, snacks
# desserts, snacks, pizzas, fastfood
# pizzas, american, italian
# southindian, beverages, sweets, thalis
# chinese, southindian, asian, indian, desserts
# pastas, icecream, pizzas
# beverages, indian, italianamerican, fastfood, chaat, chinese, mexican
# cafe, chinese, pizzas, icecream, snacks, burgers
# fastfood, pizzas, burgers, italian, snacks, american, panasian
# beverages, cafe, snacks, desserts, burgers, icecream, bakery, fastfood
# chinese, fastfood, pizzas
# cafe, icecream, snacks, burgers, fastfood, italian
# italian, pastas, beverages, snacks, desserts, pizzas, mexican, american
# beverages, burgers, snacks
# cafe, beverages
# cafe, fastfood, beverages
# pizzas, snacks, american
# snacks, northindian, beverages
# cafe, beverages, fastfood, burgers, snacks, pizzas
# southindian, northindian, mexican, italian, chinese, desserts, thalis
# beverages, pizzas, burgers, fastfood
# fastfood, desserts
# beverages, pizzas, fastfood, snacks, pastas
# continental, italian, chinese, northindian
# desserts, bakery
# cakesandpastries, bakery, desserts, sweets
# desserts, bakery, sweets
# fastfood, bakery
# bakery, icecreamcakes
# bakery, desserts, sweets
# bakery, icecreamcakes, cafe
# desserts, fastfood, cafe
# waffle, bakery, beverages
# bakery, desserts, sweets, icecream
# bakery, desserts, beverages, icecream, sweets, juices, bengali
# northindian, chinese, snacks, beverages, desserts
# southindian, icecream
# biryani, indian
# biryani, hyderabadi, pizzas
# fastfood, indian
# desserts, snacks, beverages, bakery
# northindian, southindian, snacks, chinese
# continental
# northindian, punjabi
# fastfood, beverages, snacks
# snacks, pizzas, fastfood, burgers, cafe
# chinese, northindian, punjabi
# beverages, snacks, fastfood
# snacks, burgers, pizzas, fastfood, beverages
# beverages, fastfood, burgers, pizzas, snacks
# indian, bakery
# beverages, fastfood, cafe
# cafe, beverages, indian
# beverages, fastfood, pizzas, burgers, snacks
# beverages, indian, chinese, italianamerican, fastfood
# beverages, snacks, pizzas
# indian, burmese, pastas, fastfood
# beverages, fastfood, chinese, italian
# biryani, northindian, tandoor, indian
# fastfood, indian, chaat, pizzas, beverages, desserts
# chinese, punjabi
# indian, northindian, chinese, southindian, thalis
# fastfood, pastas, chinese, snacks
# southindian, beverages, fastfood
# chinese, punjabi, southindian, beverages, pizzas, fastfood, burgers
# northindian, chinese, biryani, continental, punjabi, italian, european, mexican, thai, thalis, indian
# chaat
# punjabi, rajasthani, thai, gujarati, snacks
# northindian, thalis, fastfood
# streetfood, chaat, snacks, sweets
# burgers, snacks, beverages, fastfood
# beverages, snacks, fastfood, burgers
# desserts, beverages, grill, pastas, fastfood, burgers
# pizzas, pastas, fastfood
# cakespastries, bakery, desserts, beverages
# beverages, italianamerican, fastfood, snacks, waffle
# indian, pizzas, fastfood, burgers, chinese, cafe, beverages
# pizzas, burgers, fastfood, streetfood, beverages
# beverages, bakery, cakesandpastries, italianamerican, snacks, fastfood
# combo, indian
# beverages, icecream, desserts
# icecream, beverages, desserts
# pizzas, pastas
# tandoor, chinese, thalis, fastfood, burgers, biryani
# american, mexican
# burgers, fastfood, pizzas, mexican, beverages
# chinese, italian, beverages, snacks, pastas, fastfood
# chinese, tibetan, asian, fastfood, beverages, snacks, continental, desserts
# chinese, indian, fastfood, streetfood, asian, thai
# chinese, snacks, thai, asian, fastfood, streetfood
# chinese, fastfood, pizzas, snacks, burgers
# chinese, streetfood
# chinese, thai, momos, streetfood
# chinese, pastas
# chinese, snacks, panasian, thai, asian, fastfood, seafood, barbecue, beverages, desserts
# chinese, thai, panasian, asian, oriental
# chinese, biryani, tandoor, thalis
# chinese, asian, tibetan, desserts
# chinese, fastfood, asian
# indian, chinese, thalis, barbecue
# northindian, chinese, snacks, beverages
# beverages, fastfood, pizzas, snacks
# thalis, northindian, chinese, biryani, punjabi, fastfood
# pizzas, snacks, desserts
# beverages, pizzas
# pizzas, chinese, southindian, fastfood, streetfood, burgers, chaat, beverages, desserts
# pizzas, chinese, southindian, fastfood, streetfood, american, italian, beverages, desserts
# chinese, thalis, punjabi, gujarati, biryani
# chinese, snacks, momos, fastfood
# southindian, streetfood
# indian, chinese, desserts
# snacks, northindian, fastfood, salads
# chinese, american, continental
# indian, snacks, beverages, fastfood, pizzas
# chinese, biryani, beverages
# icecream, desserts, homefood, healthyfood
# biryani, chinese, pizzas
# desserts, bakery, beverages
# snacks, burgers, continental, fastfood
# desserts, beverages, fastfood, cafe
# beverages, waffle, desserts, snacks
# pizzas, pastas, italian, indian, american, chinese, mexican, beverages, desserts, healthyfood, snacks, salads, combo
# beverages, italian, fastfood, snacks
# beverages, continental, desserts
# beverages, pizzas, burgers
# thalis, indian
# streetfood
# waffle
# desserts, waffle
# beverages, fastfood, indian, snacks
# indian, northindian, chinese, mexican, american
# fastfood, burger, snacks, pastas
# indian, chinese, italian, tandoor, fastfood, biryani, chaat, beverages
# italian, pizzas, fastfood, burgers
# italianamerican, mexican, fastfood, beverages
# waffle, desserts, beverages
# northindian, desserts
# fastfood, northindian, beverages
# fastfood, biryani
# burger, fastfood, beverages, desserts
# beverages, fastfood, snacks
# beverages, burgers, fastfood, pizzas, snacks
# pizzas, pastas, fastfood, snacks, beverages
# snacks, beverages, fastfood, burgers
# indian, biryani
# northindian, chinese, mughlai, biryani
# southindian, homefood
# beverages, fastfood, snacks, pastas
# mughlai, beverages
# northindian, mughlai, chinese
# rajasthani, thalis, jain, gujarati, homefood, navratrispecial
# thalis, chinese, streetfood, snacks, biryani
# punjabi, thalis, indian
# chinese, snacks, burgers, beverages
# icecream, coffee
# indian, mughlai, chinese
# desserts, bakery, icecream
# bakery, icecream
# beverages, pizzas, sandwich, fastfood, pastas, burgers, rollswraps
# pizzas, bakery, chinese
# sweets, snacks
# biryani, tandoor, fastfood, shawarma, burgers
# northindian, southindian, chinese, continental, biryani, fastfood
# chinese, biryani, mughlai, beverages, barbecue
# southindian, northindian, chinese, punjabi, indian
# italian, snacks, fastfood, streetfood
# maharashtrian
# gujarati, northindian
# streetfood, fastfood
# northindian, beverages
# northindian, tandoor, snacks
# northindian, tandoor, biryani, chinese, thalis
# fastfood, streetfood, snacks, pizzas
# chinese, southindian, snacks, indian, biryani
# chinese, snacks, indian
# indian, thalis
# fastfood, gujarati
# beverages, pizzas, fastfood, burgers, cafe
# punjabi, indian
# snacks, burgers, pizzas
# southindian, northindian
# southindian, beverages
# pizzas, italianamerican, cafe
# indian, mughlai, tandoor
# chinese, healthyfood, fastfood
# northindian, chinese, tandoor, biryani
# indian, chinese, gujarati
# punjabi, nepalese, indian, assamese, naga, homefood, northeastern
# chinese, indian, beverages
# indian, punjabi, chinese, continental
# icecream, desserts, snacks
# pizzas, italian, pastas, desserts
# fastfood, snacks, beverages, northindian
# southindian, chinese, desserts
# southindian, chinese, streetfood
# southindian, southamerican
# southindian, snacks, fastfood
# mexican, salads
# beverages, northindian, snacks
# beverages, chinese
# chinese, beverages
# chinese, punjabi, fastfood
# continental, indian, mexican, desserts, beverages, chinese, healthyfood
# pizzas, pastas, cafe, burgers, beverages, desserts, fastfood
# chinese, punjabi, beverages
# snacks, pizzas, homefood, healthyfood, fastfood
# biryani, kebabs, tandoor, indian, desserts
# northindian, thalis, chinese
# pizzas, fastfood, burgers
# chinese, indian, rollswraps, biryani, mughlai, snacks
# chinese, southindian, thalis, indian, jain, gujarati, streetfood, fastfood, cafe
# chinese, italian, healthyfood
# mexican, beverages
# beverages, pizzas, snacks, fastfood
# beverages, fastfood, pizzas, waffle
# chinese, healthyfood, tandoor, pizzas, northindian, thalis, biryani
# maharashtrian, fastfood, streetfood, snacks, burgers
# northindian, streetfood, beverages
# indian, southindian, chinese, fastfood, rolls, biryani, snacks, desserts
# streetfood, fastfood, burgers, pizzas, chinese
# pizzas, snacks
# northindian, punjabi, chinese, biryani, thalis, beverages
# pizzas, desserts, beverages
# burgers, fastfood, streetfood, beverages
# indian, healthyfood
# chinese, fastfood, snacks
# italian, fastfood, snacks, beverages, desserts
# kebabs, fastfood, snacks, american, healthyfood, desserts, beverages
# fastfood, snacks, northindian, desserts, beverages
# gujarati, snacks, sweets
# mediterranean, middleeastern, lebanese
# lebanese, pizzas, beverages, italian, mexican, indian, continental, desserts, fastfood
# italianamerican, mexican, chinese, southindian, pizzas, beverages
# juices, desserts, fastfood
# icecream, sweets, beverages
# snacks, fastfood, burgers, northindian
# pizzas, pastas, italian, mexican, healthyfood, desserts, beverages
# healthyfood, beverages, juices
# pizzas, italian, fastfood
# northindian, chinese, mughlai, indian
# pizzas, burgers
# snacks, pizzas, pastas, fastfood, burgers, cafe
# northindian, gujarati, biryani, beverages
# northindian, chinese, fastfood, snacks, beverages
# bihari, indian, snacks
# punjabi, thalis
# desserts, bakery, sweets, icecream, beverages, northindian, chinese
# cakesandpastries, bakery
# asian, chinese, sushi
# biryani, punjabi, gujarati
# pizzas, burgers, fastfood, chinese
# cafe, desserts, beverages, waffle, fastfood
# pizzas, burgers, fastfood
# northindian, punjabi, chinese, tandoor, thalis
# southindian, indian, chinese
# beverages, fastfood, burgers, cafe
# northindian, middleeastern, chinese, turkish, mughlai, biryani, indian, thalis
# desserts, beverages, salads, pizzas, pastas, fastfood, burgers
# chinese, gujarati, thalis, biryani, punjabi, indian, beverages, salads
# fastfood, italian
# pizzas, burgers, beverages
# cafe, fastfood, snacks
# indian, chinese, punjabi
# fastfood, burgers, snacks, momos, pizzas
# fastfood, pizzas, beverages
# northindian, chinese, mughlai, indian, thalis
# indian, chinese, tibetan, biryani
# pizzas, beverages, icecream, burgers, fastfood, snacks
# indian, snacks, chinese, fastfood, tandoor, thalis
# fastfood, italian, snacks
# pizzas, pastas, burgers, snacks
# pizzas, italianamerican, pastas, snacks
# fastfood, snacks, rolls, rollswraps
# snacks, pizzas
# burgers, beverages
# waffle, desserts, beverages, bakery, juices
# beverages, juices, salads, healthyfood
# juices, beverages, healthyfood, salads
# beverages, juice
# southindian, chinese, fastfood, beverages
# fastfood, burgers, snacks, beverages
# chinese, biryani
# healthyfood, kathiyawadi, pureveg
# desserts, waffle, beverages, snacks
# streetfood, snacks, fastfood
# northindian, tandoor, biryani
# chinese, indian, snacks
# snacks, indian, beverages, juices
# indian, southindian, snacks, chaat, fastfood, beverages
# indian, fastfood, chaat, snacks, beverages
# fastfood, burgers, pizzas, snacks
# snacks, beverages, pizzas
# desserts, pizzas, fastfood
# fastfood, streetfood, snacks, indian
# fastfood, streetfood, snacks
# southindian, streetfood, fastfood, beverages
# beverages, streetfood, fastfood, healthyfood
# northindian, mughlai, tandoor, indian, punjabi, biryani, snacks, seafood, barbecue, grill, lucknowi, homefood, beverages, desserts, thalis
# chinese, indian, continental, healthyfood
# streetfood, chinese, indian
# punjabi, southindian, fastfood
# icecream, desserts, healthyfood, sweets
# indian, biryani, thalis, beverages
# icecream, desserts, beverages
# southindian, indian
# indian, chinese, northindian
# sweets, desserts
# italian
# indian, thalis, beverages
# fastfood, pizzas, burgers, snacks, beverages, streetfood
# indian, snacks, mughlai, northindian
# northindian, beverages, snacks, chinese
# fastfood, pizzas, burgers, gujarati, streetfood
# icecream, desserts, healthyfood
# burger
# fastfood, pizzas, burgers, snacks
# gujarati, indian, snacks
# punjabi, gujarati, thalis, chinese, sweets, fastfood, beverages
# thalis, indian, jain, gujarati, healthyfood
# northindian, snacks, fastfood
# chinese, northindian, indian, biryani, snacks
# snacks, chinese, asian, thai, fastfood, streetfood
# indian, burgers
# fastfood, snacks, beverages
# bakery, fastfood
# chinese, northindian, snacks, beverages, fastfood
# northindian, southindian, snacks, kebabs, salads, beverages
# icecreamcakes, desserts, icecream, bakery
# northindian, mughlai, chinese, continental, seafood
# gujarati, sweets, indian
# indian, chinese, tandoor
# northindian, mughlai, southindian, continental, chinese, oriental
# waffle, desserts, cafe
# waffle, desserts
# punjabi, snacks
# pizzas, italian, beverages, desserts
# pizzas, beverages
# chinese, gujarati
# southindian, streetfood, desserts
# indian, chinese, thalis, biryani, punjabi
# fastfood, southindian, snacks, beverages
# fastfood, pizzas, streetfood, snacks
# fastfood, pizzas, american, streetfood, snacks
# grill, fastfood
# northindian, mughlai, biryani, chinese, tandoor
# indian, chinese, tandoor, oriental
# gujarati, french, homefood, burgers
# pizzas, pastas, fastfood, burgers
# streetfood, gujarati, fastfood, northindian
# indian, italian
# thalis, gujarati
# desserts, sweets
# indian, southindian
# chinese, southindian, beverages, punjabi, thalis, northindian
# chinese, biryani, indian, thalis
# juices, desserts, icecream
# northindian, italian
# sweets, northindian, chinese, snacks, southindian, chaat
# punjabi, beverages, salads, pastas, fastfood, burgers, cafe
# indian, barbecue, fastfood
# barbecue, tandoor
# momos, chinese, beverages, fastfood
# italian, desserts, beverages, cafe, icecream, bakery
# chinese, punjabi, southindian, indian, tandoor, jain, gujarati, northeastern, navratrispecial, fastfood
# streetfood, fastfood, snacks
# rajasthani, gujarati
# gujarati, chinese, northindian
# northindian, snacks, chinese
# northindian, chinese, gujarati
# desserts, streetfood
# gujarati, pizzas, barbecue, fastfood, burgers
# chinese, thalis, italian, fastfood, bakery, beverages
# beverages, southindian, bakery, snacks
# punjabi, tandoor
# icecream, icecreamcakes, desserts, beverages
# icecream, pizzas
# icecreamcakes
# icecream, cakesandpastries
# icecream, beverages
# paratha, indian, snacks, beverages
# healthyfood, salads
# beverages, juices, snacks
# salads, healthyfood, cafe
# salads
# desserts, juices, salads, homefood, healthyfood, keto, cafe
# icecream, waffle, cafe, biryani
# beverages, juices, pizzas
# chinese, indian, beverages, fastfood, pizzas, burgers
# pizzas, burgers, snacks, beverages
# southindian, waffle, chinese, icecream
# salads, fastfood, cafe
# indian, punjabi, chinese, northindian, biryani, thalis
# chinese, fastfood, cafe
# snacks, fastfood, beverages, italian
# fastfood, snacks, streetfood, healthyfood, beverages
# fastfood, snacks, beverages, desserts
# icecream, desserts, bakery, cakesandpastries
# desserts, juices, salads, homefood, healthyfood
# rajasthani, indian, snacks, beverages, thalis
# thalis, gujarati, homefood
# punjabi, chinese
# northindian, fastfood, chinese
# northindian, chinese, thalis, chaat
# beverages, tandoor, punjabi
# chinese, mughlai, fastfood
# chinese, northindian, combo
# northindian, chinese, southindian
# northindian, chinese, seafood, tandoor, beverages
# mughlai, chinese, northindian
# chinese, punjabi, beverages, snacks, pizzas, fastfood
# punjabi, gujarati
# thalis, biryani
# burgers, fastfood
# mughlai, biryani, beverages
# chinese, fastfood, pizzas, snacks, burgers, beverages, icecream, continental
# northindian, chinese, oriental, tandoor, combo, indian, biryani
# chinese, punjabi, southindian, beverages, tandoor, gujarati, salads, fastfood
# northindian, mughlai, indian
# tandoor, thai, punjabi
# southindian, fastfood, beverages
# chinese, beverages, biryani, continental, desserts, snacks, italian, indian, thalis
# southindian, chinese, fastfood, pizzas, beverages
# indian, southindian, chinese, streetfood
# northindian, icecream, beverages
# northindian, mughlai, biryani, tandoor
# chinese, korean, mongolian
# chinese, panasian
# beverages, chinese, snacks, waffle
# northindian, thalis
# southindian, snacks, beverages
# desserts, pizzas, beverages, icecream, italian, pastas
# chinese, southindian, beverages, fastfood
# snacks, fastfood, beverages, pizzas
# northindian, chinese, biryani, thalis
# punjabi, chinese, biryani
# hyderabadi, biryani, northindian
# punjabi, chinese, beverages
# bakery, fastfood, pizzas, snacks, beverages
# chinese, continental, indian, mexican
# desserts, beverages, snacks, icecream
# snacks, burgers, pizzas, fastfood, asian, thai, streetfood, chinese
# streetfood, beverages, burgers, juices
# pizzas, pastas, burgers
# snacks, pizzas, fastfood
# fastfood, snacks, pizzas
# mughlai, chinese, desserts, biryani
# italian, pizzas, pastas, salads
# pizzas, italian, momos, pastas, desserts
# desserts, biryani
# indian, tandoor, chinese
# indian, chinese, thai, italian, american
# beverages, cafe, fastfood, burgers, italian, snacks, desserts
# chaat, snacks, fastfood, pizzas, streetfood
# sweets, desserts, streetfood, snacks
# desserts, northindian, pizzas
# fastfood, streetfood, snacks, desserts
# chinese, pizzas, desserts
# maharashtrian, snacks
# streetfood, southindian, snacks
# bakery, cakesandpastries
# chinese, southindian
# punjabi, thalis, beverages, gujarati
# punjabi, southindian, rajasthani, thalis, indian, jain, gujarati
# punjabi, chinese, northindian, biryani, thalis, tandoor
# gujarati, healthyfood
# gujarati, streetfood, beverages
# northindian, gujarati
# northindian, beverages, tandoor
# pizzas, snacks, fastfood
# northindian, snacks, chaat
# beverages, italian, fastfood, snacks, biryani
# italian, grill, streetfood, snacks, pizzas, fastfood, burgers
# fastfood, streetfood, chinese
# gujarati, thalis, northindian
# gujarati, northindian, thalis
# punjabi, rajasthani, jain, gujarati, northindian
# sandwich, fastfood, burgers, snacks
# indian, snacks, fastfood, burgers, pizzas, beverages
# fastfood, snacks, chaat
# chinese, punjabi, beverages, gujarati
# snacks, burgers
# southindian, icecreamcakes, cafe
# thalis, gujarati, northindian, punjabi
# punjabi, rajasthani, thalis, gujarati
# northindian, fastfood
# northindian, thalis, sweets
# snacks, streetfood, fastfood
# fastfood, gujarati, indian
# northindian, gujarati, thalis
# punjabi, thalis, indian, fastfood
# gujarati, streetfood, snacks, pizzas
# gujarati, chinese, healthyfood
# svanidhistreetfoodvendor, indian
# northindian, biryani, thalis
# indian, streetfood, fastfood
# southindian, northindian, beverages
# juices, beverages, icecream
# bakery, desserts, beverages
# southindian, gujarati, indian
# biryani, punjabi, southindian, snacks, tandoor
# desserts, italian
# pizzas, pastas, italian, desserts, beverages
# northindian, barbecue, chinese, fastfood, mexican, italian
# rajasthani, northindian
# northindian, southindian, chinese
# pastas, snacks
# thalis, indian, chinese, beverages
# biryani, salads
# maharashtrian, snacks, fastfood
# juices, beverages, healthyfood, salads, desserts
# fastfood, snacks, pizzas, burgers, beverages
# continental, punjabi, thalis, tandoor, salads, pizzas, barbecue, fastfood
# chinese, mughlai, beverages, tandoor
# pizzas, fastfood, snacks, beverages
# snacks, fastfood, rollswraps
# mexican, continental, italian, chinese, northindian
# cafe, pizzas, snacks, beverages
# beverages, fastfood, pizzas, snacks, burgers, chinese
# indian, gujarati, chinese, southindian, snacks
# tandoor, chinese, beverages
# continental, desserts, beverages, indian
# beverages, desserts, pizzas, snacks
# streetfood, snacks, fastfood, burgers
# southindian, chinese, beverages
# chinese, indian, fastfood
# northindian, pizzas, bengali
# gujarati, fastfood, streetfood, beverages
# streetfood, northindian, southindian
# beverages, chinese, indian
# northindian, italian, beverages, snacks
# snacks, beverages, tandoor, chinese, indian
# beverages, indian, chinese
# indian, chinese, northindian, biryani
# streetfood, fastfood, gujarati, beverages
# southindian, northindian, streetfood
# chinese, desserts, rolls
# streetfood, fastfood, pizzas, snacks
# northindian, tandoor, kebabs, rollswraps, seafood, biryani
# indian, northindian, beverages
# snacks, italian, chaat, beverages
# fastfood, american
# maharashtrian, snacks, fastfood, burgers, italian, beverages
# snacks, fastfood, northindian, burgers, beverages
# beverages, chaat, snacks, streetfood
# southindian, beverages, juices, gujarati, fastfood
# chinese, burgers, pastas
# indian, gujarati, jain
# gujarati, northindian, indian
# biryani, healthyfood, rajasthani, chinese
# gujarati, thalis, sweets, punjabi
# biryani, mughlai, hyderabadi, desserts, beverages
# biryani, tandoor, kebabs, snacks, desserts
# thalis, chinese, punjabi, italian
# northindian, chinese, thalis, gujarati
# beverages, icecream, desserts, healthyfood
# snacks, chaat, chinese
# burgers, fastfood, rollswraps
# arabian, northindian
# gujarati, rajasthani
# indian, punjabi
# northindian, desserts, beverages, tandoor
# punjabi, northindian, gujarati, indian
# southindian, chinese, snacks
# southindian, snacks
# sweets, snacks, gujarati
# northindian, gujarati, indian, desserts
# punjabi, thalis, fastfood, cafe
# streetfood, pizzas, fastfood, burgers, cafe
# fastfood, italian, pizzas
# punjabi, biryani, tandoor, snacks, desserts, beverages
# streetfood, fastfood, pizzas, snacks, beverages
# biryani, northindian
# gujarati, northindian, salads
# northindian, punjabi, fastfood
# fastfood, snacks, pizzas, salads, juices
# fastfood, streetfood, pizzas, rollswraps, beverages
# beverages, pizzas, desserts
# pizzas, burgers, pastas, chinese, beverages
# beverages, italianamerican, fastfood, snacks, desserts
# beverages, cafe
# indian, biryani, beverages
# chinese, pizzas
# southindian, desserts
# pizzas, waffle, fastfood, burgers, cafe
# pizzas, fastfood, cafe, chinese, southindian
# chinese, punjabi, thalis, northindian, biryani
# chinese, southindian, streetfood
# beverages, southindian, snacks
# northindian, mexican, italian, bakery, streetfood, beverages
# indian, northindian, biryani, fastfood
# beverages, juices, cafe
# chinese, northindian, indian, biryani, salads
# northindian, chinese, gujarati, biryani
# japanese, panasian
# bakery, desserts, fastfood, snacks, beverages
# pizzas, chinese, snacks
# indian, fastfood, american, chaat
# desserts, icecream, icecreamcakes
# chinese, fastfood, snacks, barbecue
# chinese, panasian, pizzas, pastas, fastfood, burgers, cafe
# american, pizzas, fastfood, snacks, chinese, beverages
# fastfood, arabian, pizzas, snacks
# italian, pizzas, pastas, desserts
# italian, pizzas
# italian, pizzas, italianamerican, fastfood
# pizzas, pastas, beverages, fastfood, italian, desserts
# pizzas, italian, beverages
# pizzas, italian, chinese
# beverages, cafe, waffle, american, burgers
# italian, grill, mexican, pizzas
# northindian, biryani, mughlai
# gujarati, streetfood
# chaat, snacks, streetfood
# chinese, asian, japanese, fastfood, panasian, southindian, thai
# icecream, desserts, snacks, juices
# beverages, juices, desserts
# indian, fastfood, snacks
# indian, fastfood, beverages
# indian, gujarati
# italian, fastfood, chinese, beverages
# northindian, biryani, tandoor
# tandoor
# northindian, mughlai, biryani, chinese
# northindian, punjabi, continental, chinese, mughlai
# thai, italian, barbecue, mexican
# desserts, bakery, icecream, icecreamcakes
# indian, italian, mexican, beverages, desserts
# southindian, fastfood, burgers
# bakery, beverages, desserts
# italian, pizzas, pastas, salads, desserts
# northindian, snacks, tandoor
# pizzas, italian, american, beverages, desserts
# pizzas, italian, italianamerican, snacks, beverages, desserts
# pizzas, pastas, desserts
# burgers, snacks, italian, desserts, beverages
# fastfood, biryani, mexican, pizzas, italian, desserts
# northindian, punjabi, healthyfood
# chinese, punjabi, mughlai, beverages, tandoor
# rajasthani, chinese, thai, fastfood, asian, streetfood
# cafe, beverages, fastfood, salads, sandwich, italian, burgers, mexican, waffle
# biryani, northindian, punjabi, healthyfood, desserts, beverages
# fastfood, snacks, streetfood, beverages
# fastfood, pavbhaji
# sindhi, pastas, indian, biryani, beverages
# pizzas, fastfood, cafe
# burgers, cafe
# indian, chinese, southindian, biryani, beverages, sweets
# italian, mexican, southindian, desserts
# biryani, mughlai, arabian
# continental, italian
# northindian, southindian
# indian, chinese, beverages, fastfood, icecream
# biryani, southindian, hyderabadi
# chaat, indian
# chinese, northindian
# streetfood, indian, chaat
# chinese, punjabi, thalis, indian, gujarati, streetfood, fastfood
# indian, thalis, chinese
# maharashtrian, fastfood, pizzas, icecream
# chinese, fastfood, icecream, beverages
# indian, punjabi, snacks, thalis
# southindian, indian, fastfood
# pizzas, streetfood, fastfood
# southindian, fastfood, indian, pizzas
# thalis, punjabi, northindian, rajasthani, gujarati
# gujarati, thalis
# mexican, streetfood, fastfood
# thalis, gujarati, fastfood, cafe
# snacks, northindian
# northindian, indian, chinese, snacks, beverages
# streetfood, northindian
# thalis, northindian, indian, punjabi, tandoor, biryani, snacks
# indian, continental, italian, mexican, pizzas, cafe, beverages, healthyfood
# rajasthani
# fastfood, snacks, burgers, pizzas
# chinese, desserts, continental, mexican, beverages, pizzas
# chinese, asian, thai
# snacks, pizzas, fastfood, beverages
# chinese, nepalese, indian
# fastfood, indian, grill, streetfood, homefood
# northindian, tandoor, fastfood
# gujarati, snacks, streetfood
# maharashtrian, northindian, biryani
# chinese, continental, american, pizzas, beverages
# chinese, thalis, biryani, italian, american, mongolian
# chinese, continental
# pizzas, pastas, italianamerican, desserts, beverages, fastfood
# pizzas, pastas, italianamerican, mexican, desserts, fastfood, beverages
# pizzas, pastas, italianamerican, fastfood, desserts, beverages
# pizzas, pastas, italian, desserts, mexican, beverages, fastfood
# pizzas, pastas, desserts, fastfood, snacks, beverages
# pizzas, pastas, desserts, beverages, fastfood, snacks
# pizzas, pastas, italian, american, mexican, fastfood, desserts, beverages
# gujarati, fastfood
# fastfood, cafe, punjabi, gujarati, pranthas
# indian, chinese, snacks
# indian, southindian, chinese, snacks
# biryani, chinese, snacks, desserts, beverages
# chaat, snacks, italian, fastfood, beverages
# american, beverages, desserts
# burgers, beverages, cafe, desserts
# northindian, chinese, gujarati, punjabi
# northindian, fastfood, snacks, beverages
# chinese, fastfood, beverages
# cafe, waffle, beverages
# beverages, pizzas, fastfood, burgers, momos, snacks, desserts
# beverages, chinese, pizzas, desserts
# chinese, continental, italian
# chinese, biryani, punjabi, maharashtrian, indian, tandoor, tribal, oriental
# northindian, thalis, jain, chinese, sweets, continental, snacks, biryani
# indian, northindian, punjabi, thalis
# beverages, desserts, snacks
# rajasthani, thalis, indian
# mexican
# snacks, italian
# northindian, tandoor, kebabs, biryani, mughlai
# waffle, desserts, beverages, bakery
# biryani, thalis
# punjabi, mexican, indian, texmex, snacks, pizzas, italianamerican, pastas, burgers, cafe
# italianamerican, fastfood, snacks, beverages
# icecream, beverages, waffle
# pizzas, fastfood, bakery
# pizzas, snacks, chinese, fastfood, burgers, streetfood, beverages
# chinese, northindian, biryani
# southindian, chettinad
# indian, tandoor
# northindian, mughlai, kebabs
# northindian, mughlai, tandoor, kebabs, biryani
# southindian, snacks, pizzas, chinese
# indian, punjabi, rajasthani, thalis, jain
# chinese, biryani, punjabi, mughlai, beverages
# sweets, snacks, bengali
# biryani, punjabi, thalis, indian, jain, gujarati, salads, homefood, healthyfood
# burgers, fastfood, pizzas
# chinese, american, beverages
# barbecue, fastfood, cafe
# bakery, beverages, snacks
# maharashtrian, fastfood, streetfood, beverages
# northindian, biryani, beverages
# american, italian
# american, italian, indian, jain, bakery, beverages, continental, desserts, pastas, pizzas, thai
# fastfood, beverages, pizzas, burgers
# indian, pizzas, beverages
# gujarati, thalis, snacks
# chinese, indian, biryani, sweets
# middleeastern, desserts
# northindian, chinese, italianamerican, fastfood, salads, snacks, biryani, beverages, thai
# fastfood, pizzas, burgers
# streetfood, northeastern, fastfood
# chinese, fastfood, streetfood
# chinese, tibetan, indian, beverages, asian, streetfood, northeastern, fastfood, momos
# chinese, tibetan, indian, beverages, asian, fastfood
# momos, tibetan
# chinese, streetfood, snacks, fastfood
# cakespastries, desserts, bakery
# bakery, snacks, fastfood
# desserts, fastfood, snacks
# indian, desserts, beverages
# beverages, desserts, bakery
# northindian, chinese, beverages
# northindian, indian, beverages
# indian, mughlai, european
# northindian, chinese, tandoor, fastfood
# mughlai, snacks, fastfood
# punjabi, tandoor, indian
# chinese, beverages, fastfood
# northindian, punjabi, beverages, indian
# beverages, fastfood, pizzas
# northindian, chinese, punjabi, biryani, fastfood
# tandoor, northindian, chinese, kebabs, biryani, desserts, beverages
# indian, rajasthani, northindian
# cafe, beverages, fastfood, snacks, sandwich, chaat
# sandwich, pizzas, burgers, snacks, pastas, mexican, desserts
# fastfood, burgers, snacks, pizzas
# indian, snacks, fastfood, chaat, beverages, juices
# northindian, fastfood, thalis, biryani
# mughlai, chinese
# french, fastfood, cafe
# streetfood, snacks, maharashtrian
# italian, fastfood, american, pizzas, burgers, beverages
# mexican, healthyfood
# mughlai, northindian, tandoor, chinese
# tandoor, chinese, biryani, snacks, kebabs
# beverages, indian
# chinese, indian
# burger, pizzas, snacks, fastfood
# fastfood, biryani, salads
# chinese, tibetan
# indian, burgers, snacks
# sweets, chinese
# juices, healthyfood, beverages, icecream, salads
# fastfood, maharashtrian
# punjabi, northindian, chinese, continental
# beverages, snacks, fastfood, pizzas, chaat
# beverages, indian, snacks, burgers
# northindian, tandoor, kebabs
# fastfood, snacks, pizzas, pastas, burgers, beverages, streetfood
# pastas, chinese, burgers, pizzas
# chinese, southindian, icecream, biryani
# fastfood, icecream
# cafe, american, chinese, streetfood, italian, beverages, desserts
# burgers, pizzas, beverages
# cafe, american, chinese, streetfood, italian, pizzas, beverages, desserts
# streetfood, snacks, jain
# mughlai, northindian, biryani, beverages
# biryani, mughlai, chinese, fastfood
# chaat, beverages, pizzas, fastfood, burgers
# indian, chinese, tandoor, seafood
# thalis, punjabi, northindian, gujarati
# fastfood, chinese, southindian, pizzas, snacks
# chinese, fastfood, streetfood, northindian
# northindian, biryani, indian
# northindian, snacks, biryani
# northindian, mughlai, chinese, biryani, tandoor
# waffle, beverages, desserts, bakery
# chinese, thai, asian, panasian
# beverages, pastas, burgers
# indian, gujarati, homefood, healthyfood
# northindian, biryani, italian
# continental, italian, lebanese, northindian, beverages, desserts, pizzas, pastas
# punjabi, beverages, jain, pizzas, pastas, fastfood
# indian, italian, snacks, mexican, korean, beverages
# chinese, mughlai, northindian
# indian, chinese, biryani, thalis
# chinese, northindian, streetfood, fastfood
# grill, tandoor, afghani, kebabs, streetfood, homefood
# northindian, mughlai, biryani
# bakery, cakespastries, icecreamcakes
# northindian, chinese, punjabi, biryani
# beverages, desserts, icecream
# beverages, fastfood, chinese
# fastfood, snacks, beverages, southindian, biryani
# beverages, italianamerican, fastfood, snacks
# snacks, chinese, beverages
# american, chinese, fastfood, pizzas, burgers, beverages
# korean
# beverages, healthyfood, salads
# beverages, salads, healthyfood
# pizzas, italian, continental, beverages
# cafe, desserts
# gujarati, northindian, punjabi, thalis, desserts
# indian, northindian, punjabi, gujarati, thalis, combo
# northindian, punjabi, beverages, snacks
# streetfood, indian, chinese, thalis
# snacks, gujarati, indian
# fastfood, biryani, chinese
# snacks, desserts, fastfood
# japanese, chinese, thai
# burgers, snacks, beverages, chinese, thai, asian, fastfood, streetfood
# northindian, chinese, continental, kebabs, salads, biryani
# bakery, pizzas, beverages
# bakery, desserts, beverages, icecream, sweets, juices, bengali, pizzas
# healthyfood, indian
# burgers, american, snacks, fastfood, beverages
# icecream, waffle
# southindian, beverages, juices, fastfood, cafe
# northindian, italian, chinese, thai
# chinese, punjabi, thalis, beverages, fastfood, cafe
# momos
# pizzas, desserts, fastfood, beverages, bakery
# pizzas, italian, fastfood, beverages
# indian, biryani, thai, chinese, asian, fastfood, streetfood
# chinese, american, southindian, beverages
# indian, beverages, chinese, punjabi
# northindian, streetfood
# punjabi, beverages, indian
# desserts, juices
# indian, snacks, chinese
# chinese, northindian, thalis
# pizzas, pastas, italian, salads
# pizzas, pastas, salads, desserts
# northindian, chinese, mughlai, seafood, punjabi, biryani, beverages, tandoor
# beverages, fastfood, gujarati, punjabi
# pastas
# chinese, desserts, beverages, icecream, snacks, pizzas, pastas, fastfood, cafe
# snacks, fastfood, streetfood, pizzas
# gujarati, beverages
# southindian, beverages, fastfood, snacks, pizzas
# northindian, chinese, fastfood, biryani, tandoor, pastas, kebabs, icecream
# pizzas, indian, chinese
# pizzas, burgers, snacks, pastas, chinese, cafe, beverages, desserts
# indian, pizzas
# homefood, fastfood
# pizzas, streetfood, burgers, beverages, italian, healthyfood
# fastfood, pizzas, snacks, beverages
# salads, desserts, beverages
# healthyfood, lebanese, salads, beverages, snacks, desserts
# middleeastern, lebanese, fastfood, arabian, northindian
# burgers, pizzas, snacks
# pizzas, italian
# pizzas, burgers, cafe
# pizzas, fastfood, mangalorean
# pizzas, pastas, burgers, beverages
# italian, fastfood, snacks
# pizzas, italian, snacks
# pizzas, indian
# italian, american, pizzas, italianamerican
# desserts, italian, pizzas, italianamerican
# pizzas, pastas, italian, fastfood
# pizzas, beverages, snacks, salads
# pizzas, snacks, desserts, beverages
# desserts, icecream, healthyfood
# goan, biryani, maharashtrian, malwani, konkan, barbecue
# mexican, pizzas
# pizzas, chinese, gujarati
# desserts, beverages, pizzas
# burger, fastfood, american
# streetfood, fastfood, beverages
# chinese, indian, momos, asian
# indian, chinese, continental, thai, mexican
# southindian, fastfood
# pizzas, southindian, chinese, beverages, burmese
# chinese, southindian, pizzas, beverages
# italian, beverages, fastfood
# punjabi, chinese, northindian
# pizzas, snacks, beverages, pastas, desserts, italian
# pizzas, desserts, fastfood
# northindian, biryani, tandoor, chinese
# northindian, kebabs, biryani, mughlai
# default
# northindian, punjabi, chinese, beverages, thalis
# punjabi, tandoor, snacks, pizzas
# northindian, snacks, seafood
# thalis, tandoor, punjabi, gujarati
# biryani, punjabi, thalis, indian, kashmiri, tandoor
# northindian, indian, biryani, desserts
# northindian, punjabi, chinese, tibetan, beverages
# rajasthani, thalis
# snacks, fastfood, beverages
# biryani, chinese, meat
# chinese, northindian, snacks
# southindian, pizzas, streetfood, northindian, beverages, desserts
# fastfood, chinese, burgers, snacks
# thalis, indian, beverages
# bakery, indian, chinese, pizzas, italian, desserts
# snacks, pastas
# indian, mughlai, snacks, northindian
# chinese, southindian, fastfood, biryani, italian
# chinese, punjabi, fastfood, thalis
# chaat, snacks, indian
# sweets, snacks, fastfood
# snacks, chaat, pizzas, burgers, fastfood
# northindian, snacks, pastas
# chinese, punjabi, southindian, streetfood
# northindian, southindian, oriental, chinese, thai, continental, american, italian, desserts
# streetfood, pizzas, rolls, fastfood
# beverages, juices, fastfood, burgers, cafe
# icecream, desserts, juices
# indian, fastfood, streetfood, pizzas, italian, burgers, gujarati, rajasthani
# indian, northindian, punjabi, desserts, biryani
# tandoor, indian
# fastfood, streetfood, pizzas
# southindian, chinese, fastfood
# mughlai, snacks, healthyfood, fastfood, afghani
# mughlai, northindian, fastfood, indian
# northindian, chinese, biryani, mughlai, tandoor, streetfood
# northindian, southindian, thalis, chinese, punjabi
# snacks, fastfood, burgers, pizzas, beverages
# indian, chinese, streetfood, beverages
# biryani, punjabi, southindian, chaat, indian, beverages, tandoor, gujarati, healthyfood
# fastfood, sandwich, burgers, pizzas, snacks, momos, chaat, waffle, beverages
# jain, streetfood, snacks, pizzas, fastfood, cafe
# chinese, punjabi, southindian, thalis, fastfood
# northindian, indian, chinese
# biryani, rajasthani, beverages, sweets
# icecream, desserts, italianamerican, icecreamcakes
# northindian, mughlai, punjabi, chinese
# mexican, fastfood, southindian
# chinese, continental, gujarati, punjabi
# snacks, indian
# streetfood, snacks, homefood, fastfood
# thalis, punjabi, mexican, beverages, italian
# chinese, mexican, beverages, fastfood
# chinese, northindian, southindian, pastas, kebabs, snacks
# gujarati, northindian, chinese
# pizzas, chinese, pastas, salads, desserts, beverages
# chinese, punjabi, mughlai, hyderabadi, indian, tandoor, kebabs, snacks, fastfood
# northindian, chinese, fastfood, snacks
# juices, snacks, icecream
# chinese, northindian, beverages
# southindian, northindian, pizzas, chaat
# chinese, indian, jain
# northindian, chinese, biryani, continental, tandoor, kebabs
# continental, pizzas, chinese, northindian, desserts, punjabi, indian, healthyfood, pastas, beverages
# thalis, desserts
# cafe, pizzas, fastfood, italian
# beverages, pizzas, snacks
# northindian, chinese, punjabi, indian, tandoor, jain, beverages
# northindian, tandoor
# punjabi, snacks, homefood, healthyfood
# northindian, mughlai, indian, tandoor
# mughlai, tandoor
# cafe, italian, mexican, healthyfood, bakery, beverages, indian
# fastfood, southindian
# chinese, italian, fastfood, snacks
# chinese, thalis, fastfood, italian, beverages
# beverages, pizzas, fastfood, burgers, snacks
# northindian, tandoor, mughlai, chinese
# pizzas, italian, pastas, continental, beverages
# chinese, beverages, waffle
# tibetan, panasian, beverages, pizzas, waffle, fastfood, burgers, cafe
# biryani, burgers
# rolls, burgers, pizzas, fastfood
# punjabi, southindian, rajasthani, thalis, indian, grill, snacks, homefood, healthyfood, navratrispecial, fastfood, burgers
# rajasthani, indian
# northindian, biryani, mughlai, indian
# pizzas, italianamerican, italian, american, desserts
# pizzas, italian, american
# northindian, pizzas, chinese
# chinese, punjabi, fastfood, beverages
# gujarati, punjabi, thalis, indian, beverages, sweets, jain, salads, homefood
# indian, chinese, punjabi, biryani
# indian, chinese, tandoor, snacks, desserts, beverages
# indian, hyderabadi, beverages
# biryani, snacks
# streetfood, chaat, snacks
# pizzas, continental, italian, american
# salads, healthyfood, rollswraps, beverages
# healthyfood
# healthyfood, salads, fastfood, beverages
# salads, beverages, healthyfood
# salads, healthyfood, beverages, juices
# salads, healthyfood, desserts
# ...
# southindian, pizzas, beverages, desserts
# chaat, fastfood
# desserts, icecream, waffle
# icecream, snacks, waffle
# chaat, streetfood, fastfood
# gujarati, snacks, northindian
# gujarati, indian
# navratrispecial
# snacks, gujarati, streetfood
# indian, chinese, continental, biryani, pizzas
# salads, healthyfood, beverages
# italian, mexican, continental, chinese, pastas, pizzas
# pizzas, american, beverages, fastfood, snacks
# chinese, biryani, burgers
# beverages, desserts, icecream, snacks
# indian, fastfood, thalis
# seafood, bengali, biryani
# punjabi, chinese, pizzas, snacks
# fastfood, snacks, northindian
# mughlai, biryani, seafood, chinese, italian
# fastfood, pizzas, burgers, momos, snacks
# biryani, indian, chinese
# mughlai, biryani, chinese, beverages
# snacks, waffle
# beverages, juices, italianamerican, fastfood
# snacks, chinese, southindian, indian, tandoor, fastfood
# beverages, pizzas, fastfood
# beverages, fastfood, italianamerican, snacks
# chinese, panasian, seafood, thai
# chaat, beverages
# northindian, chinese, punjabi
# shawarma, fastfood, rolls, snacks, beverages
# streetfood, chinese
# thalis, northindian, gujarati
# southindian, fastfood, northindian, chinese, biryani
# fastfood, southindian, snacks
# gujarati, thalis, desserts, beverages
# northindian, chinese, beverages, snacks
# fastfood, italian, snacks, beverages
# thalis, punjabi, gujarati, rajasthani, desserts
# snacks, indian, southindian
# snacks, fastfood, italian
# beverages, fastfood, snacks, burgers
# fastfood, italianamerican, chinese, mexican, beverages
# biryani, northindian, desserts, beverages
# snacks, fastfood, indian
# chinese, northindian, southindian
# thalis, punjabi, chinese, biryani, pizzas, beverages
# chinese, punjabi, gujarati
# fastfood, snacks, healthyfood
# punjabi, beverages, gujarati
# gujarati, northindian, biryani, snacks
# snacks, fastfood, thalis
# indian, desserts, gujarati
# northindian, fastfood, beverages
# icecream, beverages, continental, desserts
# chinese, momos
# southindian, fastfood, pizzas
# northindian, pizzas, fastfood
# chinese, thalis
# northindian, desserts, snacks
# gujarati, thalis, rajasthani
# chinese, northindian, fastfood
# chinese, punjabi, hyderabadi, fastfood
# snacks, jain, gujarati, sweets
# snacks, pizzas, fastfood, burgers
# northindian, chinese, fastfood, snacks, biryani
# chinese, northindian, pizzas, biryani
# chinese, rajasthani, northindian, punjabi, fastfood
# chinese, southindian, gujarati, fastfood, pizzas, sweets, beverages
# chinese, gujarati, biryani
# streetfood, fastfood, chinese
# punjabi, northindian, gujarati, fastfood, beverages
# northindian, thai, chinese, biryani, tandoor
# punjabi, chinese, southindian
# southindian, maharashtrian, snacks, northindian
# indian, chinese, streetfood, thalis
# northindian, chaat
# gujarati, southindian, northindian
# chinese, northindian, streetfood
# maharashtrian, snacks, sandwich, grill, fastfood, pizzas, burgers, beverages
# fastfood, pizzas, chinese
# gujarati, streetfood, homefood, fastfood
# southindian, chinese, punjabi, indian
# streetfood, snacks, chinese
# streetfood, southindian
# chaat, sweets, gujarati, snacks, healthyfood, fastfood
# chinese, snacks, pizzas, pastas
# streetfood, sweets
# northindian, chinese, fastfood
# northindian, chinese, continental, asian, fastfood, biryani, punjabi, beverages
# indian, parsi, continental
# parsi, indian, desserts, chinese, continental
# seafood, juices
# sindhi, snacks, beverages
# biryani, continental, punjabi, tandoor
# southindian, snacks, punjabi, maharashtrian
# mexican, pizzas, pastas
# punjabi, italian, fastfood, cafe
# italian, fastfood, snacks, mexican, beverages
# korean, momos, waffle, snacks, beverages
# mexican, italianamerican, desserts, beverages, snacks, cafe
# indian, icecream, beverages
# italian, fastfood, american, pizzas, burgers
# indian, snacks, chinese, thalis
# southindian, streetfood, beverages
# southindian, snacks, sweets
# southindian, mangalorean, beverages, desserts, streetfood
# southindian, chinese, northindian, tandoor
# chinese, pastas, pizzas, continental
# chinese, biryani, tandoor, northindian
# northindian, chinese, asian, pizzas, pastas, continental
# chinese, biryani, italian, desserts, beverages, punjabi
# tandoor, thalis, desserts
# punjabi, tandoor, chinese, thalis, mughlai, kebabs, indian
# northindian, chinese, gujarati, rajasthani, beverages
# northindian, chinese, tandoor, salads, biryani
# bengali, chinese, indian, fastfood
# thalis, punjabi, northindian
# snacks, chinese, burgers
# thalis, punjabi, gujarati
# pizzas, beverages, italian, desserts
# beverages, cafe, snacks, desserts, bakery, icecream
# streetfood, indian, pizzas
# fastfood, southindian, snacks, chinese, chaat
# healthyfood, salads, snacks, desserts, beverages
# healthyfood, salads, fastfood
# fastfood, healthyfood, salads, snacks, desserts, beverages
# fastfood, healthyfood
# bakery, burmese
# northindian, tandoor, biryani, seafood
# desserts, snacks, beverages, fastfood, burgers
# burgers, snacks, indian
# northindian, punjabi, chinese, italian
# indian, chinese, snacks, biryani
# chinese, northindian, southindian, biryani
# sushi, asian, oriental, chinese, thai, japanese, panasian
# northindian, chinese, biryani, streetfood
# juices, beverages, healthyfood
# gujarati, indian, southindian, desserts, icecream, beverages
# snacks, bakery, desserts, beverages
# italian, mediterranean, bakery, texmex, greek, snacks, pizzas, healthyfood, fastfood, cafe
# continental, healthyfood, thai, juices, mexican, mediterranean, lebanese, greek
# mexican, fastfood, snacks
# chinese, beverages, pizzas, fastfood
# northindian, southindian, chinese, tandoor, fastfood
# southindian, sweets, cafe
# chinese, mughlai, beverages
# indian, chinese, southindian, snacks
# northindian, punjabi, streetfood, tandoor
# indian, northindian, tandoor
# fastfood, snacks, indian, beverages
# italian, snacks
# italianamerican, mexican, snacks, fastfood, desserts, beverages
# fastfood, streetfood, beverages, burgers
# streetfood, snacks, pizzas, burgers, cafe
# northindian, biryani, chinese, snacks, desserts
# indian, biryani, snacks
# healthyfood, beverages, juice
# northindian, tandoor, pizzas, biryani
# indian, chinese, thai, mexican, continental, punjabi, barbecue, pastas
# chinese, punjabi, chaat, indian, snacks, pizzas, fastfood, burgers, cafe
# southindian, fastfood, snacks, chinese
# fastfood, pizzas, burgers, snacks, beverages
# maharashtrian, streetfood, fastfood, beverages
# beverages, chinese, snacks
# gujarati, fastfood, beverages, cafe, snacks
# beverages, fastfood, snacks, chinese
# beverages, snacks, continental
# beverages, fastfood, snacks, italian
# fastfood, streetfood, pizzas, beverages
# indian, pizzas, burgers, cafe
# combo, salads, indian, beverages
# beverages, northindian, italianamerican, mexican, fastfood, salads, desserts
# salads, asian, lebanese, pastas, beverages, desserts, burgers, middleeastern
# biryani, northindian, mughlai, grill
# indian, snacks, fastfood, pizzas
# northindian, beverages, desserts
# thalis, biryani, punjabi
# northindian, thalis, biryani
# healthyfood, beverages, salads, juices, snacks
# american, desserts, beverages
# pizzas, pastas, homefood, healthyfood
# indian, snacks, fastfood, seafood
# desserts, snacks, bakery
# waffle, desserts, icecream, beverages
# waffle, desserts, icecream
# biryani, mughlai, lucknowi, hyderabadi, kebabs, desserts, beverages
# chinese, fastfood, pastas, biryani, snacks
# italian, continental, pizzas
# italian, pizzas, desserts, beverages, continental
# salads, italian
# beverages, burgers
# combo
# chinese, thalis, beverages
# indian, northindian, punjabi, chinese, thalis
# snacks, rolls, momos
# northindian, snacks, punjabi, chinese, fastfood
# chaat, streetfood, fastfood, snacks
# beverages, italian, american, snacks
# bakery, desserts, beverages, fastfood, cafe
# cafe, desserts, italian, pizzas, beverages, pastas
# waffle, pizzas, fastfood, beverages
# beverages, juices, fastfood
# healthyfood, salads, juices
# continental, fastfood, healthyfood, beverages, desserts
# fastfood, burgers, snacks, beverages, chinese
# cafe, beverages, burgers, fastfood, mexican, continental, pastas, pizzas
# desserts, cakespastries, waffle, beverages
# punjabi, sweets, biryani, beverages
# beverages, italianamerican, fastfood
# northindian, chinese, tandoor, kebabs, pizzas, fastfood, snacks, beverages
# chinese, biryani, lucknowi, indian, tandoor, afghani, fastfood
# streetfood, northindian, fastfood
# northindian, chinese, tandoor, thalis
# pastas, fastfood, snacks, american
# northindian, mughlai, biryani, kebabs, seafood
# pizzas, burgers, fastfood, snacks, beverages
# navratrispecial, fastfood, cafe
# burgers, snacks, mexican
# chinese, snacks, beverages, pizzas
# bakery, waffle, beverages
# fastfood, chinese, tandoor
# juices, salads, fastfood, snacks
# beverages, juices, healthyfood
# pizzas, fastfood, snacks
# pizzas, italianamerican
# punjabi, indian, awadhi, grill, tandoor, afghani
# biryani, northindian, pastas, punjabi, desserts, beverages
# biryani, pastas, punjabi, desserts, beverages
# northeastern, gujarati, thalis
# indian, biryani, kebabs
# chinese, punjabi, mughlai, tandoor
# indian, grill
# grill, pizzas, pastas, fastfood, burgers, cafe
# northindian, chinese, afghani, biryani
# northindian, biryani, kebabs
# chinese, tandoor, kebabs, italianamerican, beverages
# snacks, juices
# desserts, chaat, beverages, juices, salads, snacks, homefood, healthyfood, fastfood, burgers
# healthyfood, fastfood, cafe
# chinese, healthyfood, fastfood, cafe
# fastfood, pastas, indian
# northindian, japanese, beverages, salads, chaat, snacks
# tibetan, chinese, momos
# grill, streetfood, snacks, pizzas, fastfood, burgers, cafe
# chinese, punjabi, biryani, fastfood
# indian, chinese, mexican, italian, fastfood
# chinese, indian, arabian, biryani, turkish, mughlai, kebabs
# biryani, punjabi
# salads, fastfood
# tandoor, beverages
# fastfood, biryani, snacks, desserts
# streetfood, korean
# beverages, fastfood, icecream, desserts
# pizzas, snacks, chaat, fastfood
# pizzas, italianamerican, beverages, snacks
# punjabi, southindian, thai, burgers
# northindian, chinese, tandoor
# mexican, beverages, desserts
# pizzas, american, snacks, beverages, streetfood, burgers
# gujarati, salads, homefood, healthyfood, cafe
# northindian, chinese, pastas, pizzas
# fastfood, salads, beverages
# beverages, snacks, chinese, fastfood, burgers
# fastfood, bakery, snacks, burgers, pastas, icecreamcakes
# northindian, pizzas, beverages
# pastas, pizzas
# waffle, beverages, icecream, desserts
# northindian, continental, chinese, snacks
# pizzas, continental, fastfood
# pizzas, italian, desserts, beverages
# fastfood, burgers, beverages, snacks
# burgers, coffee, fastfood, snacks, beverages
# snacks, mexican, italian, american, desserts
# fastfood, snacks, northindian, chinese
# pizzas, italianamerican, waffle, fastfood, burgers, beverages, cafe
# beverages, fastfood, burgers
# indian, continental, beverages
# indian, fastfood, cafe
# beverages, desserts, juices, indian
# beverages, icecream, juices, snacks, pizzas, pastas, healthyfood, cafe
# streetfood, bihari, fastfood, burgers
# tandoor, chinese, italian, snacks, fastfood, chaat
# sindhi
# southindian, salads
# chinese, arabian, grill, tandoor, streetfood, snacks, pizzas, fastfood, burgers
# indian, snacks, pizzas, fastfood
# beverages, pizzas, momos, fastfood
# rollswraps, chinese, northindian, barbecue, tandoor, pizzas, seafood
# healthyfood, salads, continental, mediterranean, indian
# desserts, beverages, icecream, waffle
# icecream, beverages, bakery
# waffle, cafe
# beverages, juices, pizzas, fastfood, snacks, icecream
# continental, italian, beverages, snacks
# fastfood, burgers, pizzas
# continental, salads, mexican, italian, asian, oriental
# indian, italian, asian, chinese
# beverages, icecream, juices, pizzas, fastfood, burgers
# italian, desserts
# nepalese, fastfood, beverages
# indian, asian, chinese, continental
# seafood, chinese, beverages
# italian, mexican, continental
# continental, pastas
# southindian, biryani, sweets, beverages, fastfood
# northindian, chinese, tandoor, biryani, sweets, beverages
# punjabi, beverages, homefood, fastfood
# chinese, streetfood, fastfood, northindian
# chinese, snacks, beverages
# pizzas, pastas, burgers, beverages, desserts
# bengali, mughlai, biryani, indian
# chinese, punjabi, beverages, fastfood
# bakery, snacks, fastfood, burgers, beverages
# snacks, indian, northindian
# seafood, snacks
# italian, indian, continental
# fastfood, salads, snacks
# southindian, chinese, pizzas, fastfood, streetfood
# northindian, southindian, chinese, fastfood, streetfood, punjabi, beverages
# southindian, punjabi, fastfood
# snacks, beverages, streetfood
# chinese, mughlai, continental
# desserts, american, continental
# southamerican, pizzas, fastfood, burgers, cafe
# icecream, desserts, waffle, beverages
# italian, continental, northindian
# northindian, chinese, snacks, salads, beverages
# southindian, maharashtrian
# kebabs, biryani, punjabi, thalis, indian, tandoor
# beverages, grill, streetfood, snacks, pizzas, pastas, waffle, fastfood, burgers, cafe
# northindian, cafe, beverages, coffee, tea, snacks, italian, american, pizzas, burgers
# northindian, chinese, continental
# northindian, snacks, thalis, beverages
# thalis, bihari, snacks, pastas, homefood, northeastern, healthyfood, fastfood, burgers
# desserts, icecream, beverages
# icecream, desserts, italian, snacks, pizzas, pastas
# healthyfood, beverages, salads
# icecream, snacks
# beverages, pastas
# chinese, biryani, thalis
# northindian, chinese, biryani, beverages
# thalis, beverages, grill, jain, gujarati, snacks, pizzas, fastfood, burgers, cafe
# mughlai, fastfood
# streetfood, indian, snacks
# pizzas, indian, american, fastfood
# mughlai, tandoor, indian, punjabi, biryani, snacks, seafood, barbecue, grill, lucknowi, homefood, beverages, desserts, thalis
# healthyfood, salads, beverages, keto
# northindian, chinese, continental, italian, healthyfood, thalis, beverages, desserts
# pizzas, chinese, fastfood, snacks, desserts, beverages
# thalis, gujarati, juices, beverages, salads
# northindian, southindian, chinese, punjabi
# waffle, desserts, bakery, beverages
# waffle, beverages
# waffle, fastfood
# desserts, waffle, beverages, cafe
# waffle, beverages, desserts
# beverages, snacks, fastfood, streetfood, desserts
# beverages, snacks, bakery
# burgers, fastfood, continental, american, beverages, desserts
# cakesandpastries, desserts
# cafe, fastfood, italian, burgers, beverages
# southindian, indian, snacks
# pastas, burgers
# burgers, american, fastfood, snacks, beverages
# pizzas, italian, burgers, snacks, beverages
# cakesandpastries
# southindian, biryani, chinese, italian, continental
# cafe, beverages, snacks, fastfood
# pizzas, fastfood, beverages, desserts
# pizzas, fastfood, italian, snacks
# continental, mexican, asian, grill, texmex, korean, barbecue, fastfood, burgers, cafe
# pizzas, italian, desserts, beverages, waffle
# indian, chinese, fastfood
# beverages, chinese, thai, asian, fastfood, streetfood
# chinese, thai, oriental, asian, panasian
# southindian, snacks, fastfood, beverages
# waffle, beverages, icecream
# snacks, indian, waffle
# tibetan, chinese, asian, snacks, continental, desserts, beverages
# tibetan, healthyfood, asian, chinese, snacks, continental, desserts, beverages
# italian, pizzas, jain
# burgers, pizzas, salads, beverages
# pizzas, continental, beverages
# desserts, beverages, bakery, snacks
# pizzas, chinese, northindian
# snacks, pastas, fastfood
# continental, chinese, pizzas, italian, salads, mexican, desserts
# rolls, burgers, momos, beverages
# chinese, italian, beverages, punjabi
# fastfood, italianamerican, snacks, beverages
# southindian, indian, gujarati, snacks
# fastfood, snacks, burgers, pizzas, streetfood
# beverages, fastfood, snacks, pizzas
# meat, mughlai
# biryani, fastfood, tandoor, pizzas, shawarma, snacks
# northindian, chinese, southindian, fastfood, snacks, sweets, thalis
# punjabi, chinese, gujarati, biryani
# snacks, fastfood, indian, beverages
# european, pizzas, pastas
# thalis, punjabi, beverages, desserts
# chinese, biryani, pastas, barbecue
# mughlai, grill, tandoor, pastas, oriental, fastfood
# pastas, burgers, cafe
# indian, chinese, continental, northindian, southindian, oriental, thai, american, italian, desserts
# fastfood, burgers, snacks, chaat
# desserts, beverages, juices, fastfood, burgers, cafe
# beverages, pizzas, momos, sandwich, snacks, fastfood, rollswraps, grill, pastas, mexican
# beverages, pizzas, fastfood, burgers
# burgers, pastas, snacks, beverages

# %%
def rp(city, user_cuisines=None, num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2):
    df_city = dfc[dfc['city'] == city]
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city.loc[:, ['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
    # Check if user-provided cuisines exist in the dataset
    message = ""
    if user_cuisines:
        available_cuisines = df_city['cuisines'].str.lower().unique()
        user_cuisines_lower = [c.lower() for c in user_cuisines]
        
        # If none of the user-provided cuisines exist in the dataset
        if not any(cuisine in ', '.join(available_cuisines) for cuisine in user_cuisines_lower):
            return f"No restaurants offering the requested cuisines: {', '.join(user_cuisines)}."
        
        # If the cuisines are present but less popular, display the message
        popular_cuisines_threshold = 3  # Set a threshold for considering cuisines "less popular"
        matched_cuisines = [c for c in user_cuisines_lower if any(c in cuisine for cuisine in available_cuisines)]
        
        if len(matched_cuisines) < popular_cuisines_threshold:
            message = "Dear user, your requested cuisine(s) are less popular, so the recommendations are based on overall higher ratings, higher cuisines similarity score , or distance."
    
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity +
                           distance_weight * distance_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
    # Return the recommendations along with the message if cuisines were less popular
    if message:
        print(message)
    
    return top_recommendations_overall

# %%
# Example usage:
rp(city='mehsana', user_cuisines=['chinese'])
# Out:
# Dear user, your requested cuisine(s) are less popular, so the recommendations are based on overall higher ratings, higher cuisines similarity score , or distance.
# ['krishna restaurant',
#  'hotel highlaned',
#  'jay bhavani vadapav',
#  'neelkanth restaurant',
#  'hotel tulsi']

# %%
def rq(city, user_cuisines=None, num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2):
    df_city = dfc[dfc['city'] == city]
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city.loc[:, ['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
    # Define the popularity threshold
    popular_cuisines_threshold = 2

    message = None  # To store message if needed
    
    # If user_cuisines are provided, ensure they exist in the dataset
    if user_cuisines:
        available_cuisines = df_city['cuisines'].str.lower().unique()
        user_cuisines_lower = [c.lower() for c in user_cuisines]
        
        # Count the number of matching cuisines
        matching_cuisines_count = sum(cuisine in ', '.join(available_cuisines) for cuisine in user_cuisines_lower)
        
        if matching_cuisines_count == 0:
            return f"No restaurants offering the requested cuisines: {', '.join(user_cuisines)}."
        elif matching_cuisines_count < popular_cuisines_threshold:
            message = ("Dear user, your requested cuisine(s) are less popular, so the recommendations are "
                       "based on overall higher ratings, similar cuisines, or distance.")
    
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity +
                           distance_weight * distance_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
    # Return the message along with the recommendations
    if message:
        return message, top_recommendations_overall
    else:
        return top_recommendations_overall

# %%
dd=dfc['cuisines'].value_counts()

# %%
dd[dd<3].sort_values(ascending=False).head(60)
# Out:
# cuisines
# indian, chinese, northindian                                                                                           2
# burgers, american, fastfood, snacks                                                                                    2
# beverages, pizzas, fastfood, burgers, cafe, snacks, momos, mexican, waffle, desserts                                   2
# american, cafe                                                                                                         2
# fastfood, snacks, northindian, chinese                                                                                 2
# burgers, coffee, fastfood, snacks, beverages                                                                           2
# sandwich, snacks, burgers, pizzas, beverages                                                                           2
# waffle, beverages, icecream, desserts                                                                                  2
# bengali, biryani, tandoor                                                                                              2
# indian, chinese, homefood, healthyfood                                                                                 2
# burgers, snacks, pizzas                                                                                                2
# mexican, continental, asian                                                                                            2
# desserts, burgers, bakery                                                                                              2
# indian, chinese, continental, northindian, biryani, punjabi, thalis, tandoor, pastas, snacks, beverages, streetfood    2
# pizzas, italianamerican, beverages, snacks                                                                             2
# bakery, desserts, waffle, beverages                                                                                    2
# salads, fastfood                                                                                                       2
# pastas, pizzas                                                                                                         2
# beverages, pizzas, momos, fastfood                                                                                     2
# northindian, chinese, indian                                                                                           2
# mediterranean, middleeastern, lebanese                                                                                 2
# chinese, northindian, punjabi                                                                                          2
# beverages, juices, healthyfood                                                                                         2
# desserts, bakery, sweets                                                                                               2
# bakery, icecreamcakes, cafe                                                                                            2
# bakery, waffle, beverages                                                                                              2
# waffle, bakery, beverages                                                                                              2
# desserts, snacks, beverages, bakery                                                                                    2
# snacks, pizzas, fastfood, burgers, cafe                                                                                2
# beverages, fastfood, burgers, pizzas, snacks                                                                           2
# indian, desserts                                                                                                       2
# indian, bakery                                                                                                         2
# beverages, fastfood, pizzas, burgers, snacks                                                                           2
# burgers, fastfood, snacks, beverages                                                                                   2
# burgers, american                                                                                                      2
# american                                                                                                               2
# chinese, indian, arabian, biryani, turkish, mughlai, kebabs                                                            2
# beverages, juices, pizzas, fastfood, snacks, icecream                                                                  2
# italianamerican, mexican, fastfood, beverages                                                                          2
# northindian, desserts                                                                                                  2
# pizzas, italian, beverages, desserts                                                                                   2
# northindian, southindian, oriental, chinese, thai, continental, american, italian, desserts                            2
# icecream, desserts, italianamerican, icecreamcakes                                                                     2
# snacks, fastfood, rollswraps                                                                                           2
# mexican, continental, italian, chinese, northindian                                                                    2
# snacks, fastfood, burgers, pizzas, beverages                                                                           2
# indian, fastfood, streetfood, pizzas, italian, burgers, gujarati, rajasthani                                           2
# southindian, northindian, streetfood                                                                                   2
# beverages, juices, fastfood, burgers, cafe                                                                             2
# beverages, chaat, snacks, streetfood                                                                                   2
# maharashtrian, snacks, fastfood                                                                                        2
# northindian, barbecue, chinese, fastfood, mexican, italian                                                             2
# indian, tandoor, chinese                                                                                               2
# desserts, biryani                                                                                                      2
# chinese, punjabi, fastfood, beverages                                                                                  2
# southindian, fastfood, pizzas                                                                                          2
# icecream, beverages, continental, desserts                                                                             2
# indian, chinese, tandoor                                                                                               2
# fastfood, snacks, pizzas, burgers, beverages                                                                           2
# biryani, salads                                                                                                        2
# Name: count, dtype: int64

# %%
df[df['restaurant_name']=='lapinoz']
# Out:
# Empty DataFrame
# Columns: [restaurant_name, ratings, cuisines, address, distance, city, pricing_impute]
# Index: []

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd
from scipy.stats import spearmanr

def k(city, user_cuisines=None, num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2, expert_ranking=None):
    df_city = dfc[dfc['city'] == city]
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city.loc[:, ['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
    # If user_cuisines are provided, ensure they exist in the dataset
    if user_cuisines:
        available_cuisines = df_city['cuisines'].str.lower().unique()
        user_cuisines_lower = [c.lower() for c in user_cuisines]
        
        # Check if any of the requested cuisines exist in the dataset
        if not any(cuisine in ', '.join(available_cuisines) for cuisine in user_cuisines_lower):
            return f"No restaurants offering the requested cuisines: {', '.join(user_cuisines)}."
        
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity +
                           distance_weight * distance_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
    # If an expert ranking is provided, calculate Spearman's Rank Correlation
    if expert_ranking is not None:
        # Ensure the expert ranking and system ranking have the same length
        expert_ranking = [r for r in expert_ranking if r in top_recommendations_overall]  # Filter expert_ranking to contain only restaurants in the system recommendations
        
        # Get the ranks for both lists
        system_ranking = top_recommendations_overall[:len(expert_ranking)]
        
        # Convert the rankings into a numerical format
        system_ranks = [system_ranking.index(r) for r in system_ranking]
        expert_ranks = [expert_ranking.index(r) for r in expert_ranking]
        
        # Calculate Spearman's correlation coefficient
        spearman_corr, _ = spearmanr(system_ranks, expert_ranks)
        
        return top_recommendations_overall, spearman_corr
    
    return top_recommendations_overall

# %%
# Example expert-provided ranking for the city 'mehsana' with Chinese cuisine preference
expert_ranking = ['krishna restaurant', 'jay ambe fastfood','jay bhavani vadapav','neelkanth restaurant','hotel tulsi']



# Call the function with the expert ranking to calculate Spearman’s correlation
recommendations, spearman_corr = k(city='mehsana', user_cuisines=['chinese'], expert_ranking=expert_ranking)

print(f"Top Recommendations: {recommendations}")
print(f"Spearman Correlation with Expert Ranking: {spearman_corr}")
# Out:
# Top Recommendations: ['krishna restaurant', 'hotel highlaned', 'jay bhavani vadapav', 'neelkanth restaurant', 'hotel tulsi']
# Spearman Correlation with Expert Ranking: 1.0

# %%
dfc1=dfc.copy()

# %%
dfc1.shape
# Out:
# (4091, 7)

# %%
new=pd.DataFrame([{'restaurant_name':"gordhan thal",
    'ratings':4.4,
    'cuisines':'gujarati',
    'address':'sarkhej road',
    'distance':28.0,
    'city':'ahmedabad',
    'pricing_impute':200}])

# %%
dfc1=pd.concat([dfc1,new],ignore_index=True)

# %%
dfc1[(dfc1['city']=='ahmedabad') & (dfc1['restaurant_name']=="gordhan thal")]
# Out:
#      restaurant_name  ratings       address  distance       city  cuisines  \
# 4091    gordhan thal      4.4  sarkhej road      28.0  ahmedabad  gujarati
#
#       pricing_impute
# 4091           200.0

# %%
def rl(city, user_cuisines=None,num_recommendations=5,cuisines_weight=0.5,ratings_weight=0.3,distance_weight=0.2):
    df_city = dfc1[dfc1['city'] == city]
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city.loc[:,['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
     # If user_cuisines are provided, ensure they exist in the dataset
    if user_cuisines:
        available_cuisines = df_city['cuisines'].str.lower().unique()
        user_cuisines_lower = [c.lower() for c in user_cuisines]
        
        # Check if any of the requested cuisines exist in the dataset
        if not any(cuisine in ', '.join(available_cuisines) for cuisine in user_cuisines_lower):
            return f"No restaurants offering the requested cuisines: {', '.join(user_cuisines)}."
        
    
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity +
                           distance_weight * distance_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
    
    return top_recommendations_overall


# r(city='mehsana', user_cuisines=['chinese'])

# %%
rl(city='ahmedabad',user_cuisines=['gujarati'])
# Out:
# ['annkut',
#  'hari om centre',
#  'maharaja restaurant',
#  'shiv shakti fast food',
#  'gordhan thal']

# %%
dfc1[(dfc1['city']=='ahmedabad') & (dfc1['restaurant_name']=="annkut")]
# Out:
#     restaurant_name  ratings        address  distance       city  cuisines  \
# 180          annkut      4.5  prahlad nagar      38.0  ahmedabad  gujarati
#
#      pricing_impute
# 180           209.0

# %%
dfc1[(dfc1['city']=='mehsana') & (dfc1['restaurant_name']=="hungritos")]
# Out:
#      restaurant_name  ratings  address  distance     city  \
# 1467       hungritos      3.7  mehsana      32.0  mehsana
#
#                                  cuisines  pricing_impute
# 1467  snacks, fastfood, beverages, pizzas           250.0

# %%
def w(city, user_cuisines=None, num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2):
    df_city = dfc[dfc['city'] == city]
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city.loc[:,['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
     # If user_cuisines are provided, ensure they exist in the dataset
    if user_cuisines:
        available_cuisines = df_city['cuisines'].str.lower().unique()
        user_cuisines_lower = [c.lower() for c in user_cuisines]
        
        # Check if any of the requested cuisines exist in the dataset
        if not any(cuisine in ', '.join(available_cuisines) for cuisine in user_cuisines_lower):
            return f"No restaurants offering the requested cuisines: {', '.join(user_cuisines)}."
        
    
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity +
                           distance_weight * distance_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
    
    return top_recommendations_overall


# r(city='mehsana', user_cuisines=['chinese'])

# %%
w(city='mehsana', user_cuisines=['snacks'])
# Out:
# ['hungritos',
#  'murli food home-radhanpur road',
#  'hotel highlaned',
#  'shakti - the sandwich shop',
#  'sejan chinese & punjabi']

# %%
dfc1[(dfc1['city']=='mehsana') & (dfc1['restaurant_name']=="zorko brand of food lovers")]
# Out:
#                  restaurant_name  ratings  address  distance     city  \
# 4087  zorko brand of food lovers      5.0  mehsana      28.0  mehsana
#
#                                   cuisines  pricing_impute
# 4087  beverages, pizzas, fastfood, burgers            40.0

# %%
dfc1['cuisines']
# Out:
# 0                 arabian, continental, american, turkish
# 1                 arabian, continental, american, turkish
# 2                                         snacks, chinese
# 3                                     northindian, pizzas
# 4       indian, chinese, continental, desserts, beverages
#                               ...
# 4087                 beverages, pizzas, fastfood, burgers
# 4088                                               pastas
# 4089                   burgers, pastas, snacks, beverages
# 4090                                      thalis, biryani
# 4091                                             gujarati
# Name: cuisines, Length: 4092, dtype: object

# %%
dfc
# Out:
#                  restaurant_name  ratings        address  distance  \
# 0                      #shawarma      4.4    navrangpura      32.0
# 1                      #shawarma      4.4    navrangpura     102.0
# 2                      159 diner      3.3    gandhinagar      28.0
# 3       1944 - the hocco kitchen      4.5       sargasan      28.0
# 4       1944 - the hocco kitchen      4.5     sayajiganj      28.0
# ...                          ...      ...            ...       ...
# 4086  zorko brand of food lovers      4.1  mahadev nagar      38.0
# 4087  zorko brand of food lovers      5.0        mehsana      28.0
# 4088  zorko-brand of food lovers      4.3         naroda      82.0
# 4089                         zoy      4.1      ghatlodia      72.4
# 4090                         zuk      4.4       kankaria      28.0
#
#              city                                           cuisines  \
# 0       ahmedabad            arabian, continental, american, turkish
# 1     gandhinagar            arabian, continental, american, turkish
# 2     gandhinagar                                    snacks, chinese
# 3     gandhinagar                                northindian, pizzas
# 4        vadodara  indian, chinese, continental, desserts, beverages
# ...           ...                                                ...
# 4086        anand  beverages, pizzas, momos, sandwich, snacks, fa...
# 4087      mehsana               beverages, pizzas, fastfood, burgers
# 4088  gandhinagar                                             pastas
# 4089  gandhinagar                 burgers, pastas, snacks, beverages
# 4090    ahmedabad                                    thalis, biryani
#
#       pricing_impute
# 0              100.0
# 1              129.0
# 2               80.0
# 3              150.0
# 4               75.0
# ...              ...
# 4086            50.0
# 4087            40.0
# 4088            99.0
# 4089           100.0
# 4090            40.0
#
# [4091 rows x 7 columns]

# %%
dfc.shape
# Out:
# (4091, 7)

# %%
df.shape
# Out:
# (4092, 7)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Function to provide recommendations based on city, cuisine, and a specific restaurant
def get_recommendations(df):
    # Get user input for city, cuisine, and restaurant name
    selected_city = input("Enter the city: ")
    selected_cuisine = input("Enter the cuisine: ")
    restaurant_name = input("Enter the restaurant name:")

    # Filter data for the specific city and cuisine
    filtered_df = df[(df['city'] == selected_city) & (df['cuisines'].str.contains(selected_cuisine, case=False))].reset_index(drop=True)
    
    # Check if there are enough restaurants after filtering
    if len(filtered_df) < 2:
        print(f"Not enough restaurants in {selected_city} for the cuisine '{selected_cuisine}' to provide recommendations.")
        return
    
    # Apply TF-IDF on 'cuisines' for the filtered data
    tfidf = TfidfVectorizer()
    tfidf_matrix = tfidf.fit_transform(filtered_df['cuisines'])
    
    # Check if the restaurant exists in the filtered dataset
    if restaurant_name not in filtered_df['restaurant_name'].values:
        print(f"The restaurant '{restaurant_name}' was not found in {selected_city} for the cuisine '{selected_cuisine}'.")
        return
    
    # Find the index of the selected restaurant
    restaurant_idx = filtered_df[filtered_df['restaurant_name'] == restaurant_name].index[0]
    
    # Calculate cosine similarity between the selected restaurant and all others
    cosine_similarities = cosine_similarity(tfidf_matrix[restaurant_idx], tfidf_matrix)
    
    # Get indices of the top 3 most similar restaurants
    similar_indices = cosine_similarities[0].argsort()[-6:][::-1]  # Get top 3 most similar excluding the restaurant itself
    
    # Exclude the first index (which will be the restaurant itself)
    similar_indices = similar_indices[1:]
    
    # Get the names of the recommended restaurants
    recommended_restaurants = filtered_df.iloc[similar_indices]['restaurant_name']
    
    # Print the recommended restaurants
    print(f"\nRecommendations for '{restaurant_name}' in {selected_city}:")
    print(recommended_restaurants.values)

# Sample DataFrame (modify this with your actual data)


# Get recommendations based on user inputt
get_recommendations(df)
# Out:
# Enter the city:
# Enter the cuisine:
# Enter the restaurant name:
# Not enough restaurants in  for the cuisine '' to provide recommendations.

# %%
dfc1[(dfc1['city']=='mehsana') & (dfc1['restaurant_name']=="hotel tulsi")]
# Out:
#      restaurant_name  ratings  address  distance     city  \
# 1447     hotel tulsi      4.3  mehsana      32.0  mehsana
#
#                                                cuisines  pricing_impute
# 1447  southindian, chinese, fastfood, pizzas, beverages            80.0

# %%
def get_recommendations(df, num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.3):
    # Get user input for city, cuisine, and optionally restaurant name
    selected_city = input("Enter the city: ")
    selected_cuisine = input("Enter the cuisine: ")
    restaurant_name = input("Enter the restaurant name (or press Enter to skip): ")

    # Filter data for the specific city and cuisine
    df_city = df[(df['city'] == selected_city) & (df['cuisines'].str.contains(selected_cuisine, case=False))].reset_index(drop=True)
    
    # Check if there are enough restaurants after filtering
    if len(df_city) < 2:
        print(f"Not enough restaurants in {selected_city} for the cuisine '{selected_cuisine}' to provide recommendations.")
        return
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city[['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])

    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_matrix = tfidf.fit_transform(df_city['cuisines'])

    # Compute similarity matrices for cuisines, ratings, and distance
    cuisine_similarity = cosine_similarity(cuisine_matrix)
    rating_similarity = cosine_similarity(df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']])

    # Check if a specific restaurant name is provided
    if restaurant_name:
        # Ensure the restaurant exists in the filtered data
        if restaurant_name not in df_city['restaurant_name'].values:
            print(f"The restaurant '{restaurant_name}' was not found in {selected_city} for the cuisine '{selected_cuisine}'.")
            return

        # Find the index of the selected restaurant
        restaurant_idx = df_city[df_city['restaurant_name'] == restaurant_name].index[0]

        # Calculate weighted similarity using specified weights
        weighted_similarity = (
            cuisines_weight * cuisine_similarity[restaurant_idx] +
            ratings_weight * rating_similarity[restaurant_idx] +
            distance_weight * distance_similarity[restaurant_idx]
        )

        # Get indices of the top recommendations
        recommendations_idx = np.argsort(weighted_similarity)[-num_recommendations-1:][::-1]

        # Remove the restaurant itself from recommendations
        recommendations_idx = [idx for idx in recommendations_idx if idx != restaurant_idx][:num_recommendations]

        # Get the recommended restaurants
        recommended_restaurants = df_city.iloc[recommendations_idx]
        
        print(f"\nRecommendations similar to '{restaurant_name}' in {selected_city}:")
    
    else:
        # Aggregate similarity scores for all restaurants when no specific restaurant is provided
        cuisine_scores = cuisine_similarity.sum(axis=0)
        rating_scores = rating_similarity.sum(axis=0)
        distance_scores = distance_similarity.sum(axis=0)

        # Calculate weighted similarity for all restaurants
        weighted_similarity = (
            cuisines_weight * cuisine_scores +
            ratings_weight * rating_scores +
            distance_weight * distance_scores
        )

        # Get indices of the top recommendations
        recommendations_idx = np.argsort(weighted_similarity)[-num_recommendations:][::-1]

        # Get the recommended restaurants
        recommended_restaurants = df_city.iloc[recommendations_idx]
        
        print(f"\nTop {num_recommendations} recommendations in {selected_city} for cuisine '{selected_cuisine}':")
    
    # Display the recommendations
    print(recommended_restaurants[['restaurant_name', 'ratings', 'address', 'cuisines', 'distance']])

# Sample usage with a DataFrame (make sure to replace df with your actual data)
get_recommendations(df)
# Out:
# Enter the city:
# Enter the cuisine:
# Enter the restaurant name (or press Enter to skip):
# Not enough restaurants in  for the cuisine '' to provide recommendations.

# %%
def get(selected_city,selected_cuisine,restaurant_name=None,num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.3):
    # Get user input for city, cuisine, and optionally restaurant name


    # Filter data for the specific city and cuisine
    df_city = dfc[(dfc['city'] == selected_city) & (dfc['cuisines'].str.contains(selected_cuisine, case=False))].reset_index(drop=True)
    
    # Check if there are enough restaurants after filtering
    if len(df_city) < 2:
        print(f"Not enough restaurants in {selected_city} for the cuisine '{selected_cuisine}' to provide recommendations.")
        return
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    df_city[['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    
    df_city['ratings_origin']=df_city['ratings']
    df_city['distance_origin']=df_city['distance']

    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_matrix = tfidf.fit_transform(df_city['cuisines'])

    # Compute similarity matrices for cuisines, ratings, and distance
    cuisine_similarity = cosine_similarity(cuisine_matrix)
    rating_similarity = cosine_similarity(df_city[['ratings']])
    distance_similarity = cosine_similarity(df_city[['distance']])

    # Check if a specific restaurant name is provided
    if restaurant_name:
        # Ensure the restaurant exists in the filtered data
        if restaurant_name not in df_city['restaurant_name'].values:
            print(f"The restaurant '{restaurant_name}' was not found in {selected_city} for the cuisine '{selected_cuisine}'.")
            return

        # Find the index of the selected restaurant
        restaurant_idx = df_city[df_city['restaurant_name'] == restaurant_name].index[0]

        # Calculate weighted similarity using specified weights
        weighted_similarity = (
            cuisines_weight * cuisine_similarity[restaurant_idx] +
            ratings_weight * rating_similarity[restaurant_idx] +
            distance_weight * distance_similarity[restaurant_idx]
        )

        # Get indices of the top recommendations
        recommendations_idx = np.argsort(weighted_similarity)[-num_recommendations-1:][::-1]

        # Remove the restaurant itself from recommendations
        recommendations_idx = [idx for idx in recommendations_idx if idx != restaurant_idx][:num_recommendations]

        # Get the recommended restaurants
        recommended_restaurants = df_city.iloc[recommendations_idx]
        
        print(f"\nRecommendations similar to '{restaurant_name}' in {selected_city}:")
    
    else:
        # Aggregate similarity scores for all restaurants when no specific restaurant is provided
        cuisine_scores = cuisine_similarity.sum(axis=0)
        rating_scores = rating_similarity.sum(axis=0)
        distance_scores = distance_similarity.sum(axis=0)

        # Calculate weighted similarity for all restaurants
        weighted_similarity = (
            cuisines_weight * cuisine_scores +
            ratings_weight * rating_scores +
            distance_weight * distance_scores
        )

        # Get indices of the top recommendations
        recommendations_idx = np.argsort(weighted_similarity)[-num_recommendations:][::-1]

        # Get the recommended restaurants
        recommended_restaurants = df_city.iloc[recommendations_idx]
        
        print(f"\nTop {num_recommendations} recommendations in {selected_city} for cuisine '{selected_cuisine}':")
    
    # Display the recommendations
    print(recommended_restaurants[['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'distance_origin']])

# Sample usage with a DataFrame (make sure to replace df with your actual data)

# %%
get(selected_city='mehsana',selected_cuisine='pizzas')
# Out:
# Top 5 recommendations in mehsana for cuisine 'pizzas':
#                restaurant_name  ratings_origin  address  \
# 29  zorko brand of food lovers        1.000000  mehsana
# 11          jay ambe fast food        0.461538  mehsana
# 18                  patel cafe        0.538462  mehsana
# 8              hotel highlaned        0.538462  mehsana
# 3             bhukhkhad's cafe        0.307692  mehsana
#
#                                              cuisines  distance_origin
# 29               beverages, pizzas, fastfood, burgers           0.5000
# 11                        fastfood, pizzas, beverages           0.2000
# 18  chinese, desserts, beverages, icecream, snacks...           0.3000
# 8   chinese, punjabi, beverages, snacks, pizzas, f...           0.5400
# 3   desserts, beverages, salads, snacks, pizzas, p...           0.1335

# %%
def rp_or_get_recommendations(city, user_cuisines='fastfood', num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2, restaurant_name=None):
    """
    Recommends restaurants based on either:
    - City and cuisine preferences (first logic), or
    - A specific restaurant's name (second logic).
    """
    
    # If restaurant_name is provided, use the second logic for recommendations
    if restaurant_name:
        # Filter data for the specific city and cuisine
        filtered_df = dfc[(dfc['city'] == city) & (dfc['cuisines'].str.contains(user_cuisines, case=False))].reset_index(drop=True)
        
        # Check if there are enough restaurants after filtering
        if len(filtered_df) < 2:
            print(f"Not enough restaurants in {city} for the cuisine '{user_cuisines}' to provide recommendations.")
            return
        
        # Apply TF-IDF on 'cuisines' for the filtered data
        tfidf = TfidfVectorizer()
        tfidf_matrix = tfidf.fit_transform(filtered_df['cuisines'])
        
        # Check if the restaurant exists in the filtered dataset
        if restaurant_name not in filtered_df['restaurant_name'].values:
            print(f"The restaurant '{restaurant_name}' was not found in {city} for the cuisine '{user_cuisines}'.")
            return
        
        # Find the index of the selected restaurant
        restaurant_idx = filtered_df[filtered_df['restaurant_name'] == restaurant_name].index[0]
        
        # Calculate cosine similarity between the selected restaurant and all others
        cosine_similarities = cosine_similarity(tfidf_matrix[restaurant_idx], tfidf_matrix)
        
        # Get indices of the top 5 most similar restaurants
        similar_indices = cosine_similarities[0].argsort()[-(num_recommendations + 1):][::-1]  # Get top 5 most similar excluding the restaurant itself
        
        # Exclude the first index (which will be the restaurant itself)
        similar_indices = similar_indices[1:]
        
        # Get the names of the recommended restaurants
        recommended_restaurants = filtered_df.iloc[similar_indices]['restaurant_name']
        
        # Print the recommended restaurants
        print(f"\nRecommendations for '{restaurant_name}' in {city}:")
        print(recommended_restaurants.values)
        return

    # If no restaurant_name is provided, use the first logic for recommendations
    else:
        df_city = dfc[dfc['city'] == city]
        df_city['ratings_origin'] = df_city['ratings']
        

        # Scale ratings and distance 
        scaler = MinMaxScaler()
        df_city.loc[:, ['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])

        # Compute TF-IDF for cuisines
        tfidf = TfidfVectorizer()
        cuisine_metric = tfidf.fit_transform(df_city['cuisines'])

        message = ""
        if user_cuisines:
            available_cuisines = df_city['cuisines'].str.lower().unique()
            user_cuisines_lower = [c.lower() for c in user_cuisines]

            # Check if user-provided cuisines exist in the dataset
            matched_cuisines = [c for c in user_cuisines_lower if any(c in cuisine for cuisine in available_cuisines)]

            if not matched_cuisines:  # No matching cuisines found
                return pd.DataFrame(columns=['restaurant_name', 'ratings_origin', 'address', 'cuisines',
                                             'distance_origin']), "No restaurants offering the requested cuisines: {}".format(', '.join(user_cuisines))

            # If the cuisines are present but less popular
            if len(matched_cuisines) < 2:
                message = "Dear user, your requested cuisine(s) are less popular, so the recommendations are based on overall higher ratings, higher cuisines similarity score, or distance."

        # Compute similarity matrices
        rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
        distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
        np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
        cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)

        # Apply user preferences to cuisine similarity
        if user_cuisines:
            user_cuisines_str = ', '.join(user_cuisines)
            user_cuisine_vector = tfidf.transform([user_cuisines_str])
            user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()

            # Boost cuisine similarity for matching restaurants
            cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]

        # Calculate weighted similarity
        weighted_similarity = (cuisines_weight * cuisine_similarity +
                               ratings_weight * rating_similarity +
                               distance_weight * distance_similarity)

        # Create similarity DataFrame
        similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'],
                                     index=df_city['restaurant_name'])

        # Aggregate similarity scores for all restaurants
        aggregated_scores = similarity_df.sum(axis=0)

        # Get the top N recommendations based on aggregated scores
        top_recommendations = aggregated_scores.nlargest(num_recommendations).index.tolist()

        # Create a DataFrame for the top recommendations with specific columns
        top_recommendations_df = df_city[df_city['restaurant_name'].isin(top_recommendations)].copy()

        # Select only the specified columns
        top_recommendations_df = top_recommendations_df[
            ['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']]

        # Add a message column to the recommendations DataFrame
        top_recommendations_df['message'] = message

        return top_recommendations_df, message

# %%
rp_or_get_recommendations(city='mehsana',user_cuisines='pizzas')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15600\1116102242.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['ratings_origin'] = df_city['ratings']
# (          restaurant_name  ratings_origin  address  \
#  22       7 heart pizzeria             4.2  mehsana
#  93             al - shahi             4.0  mehsana
#  108  all by biryani chefs             3.2  mehsana
#  148      amrutsari kulcha             4.4  mehsana
#  227   ashapura restaurant             4.4  mehsana
#
#                           cuisines  pricing_impute message
#  22               pizzas, fastfood            80.0
#  93               mughlai, biryani           100.0
#  108   biryani, mughlai, beverages            50.0
#  148            punjabi, beverages            89.0
#  227  pizzas, northindian, chinese            40.0          ,
#  '')

# %%
def rp_or_get_recommendations2(city, user_cuisines='fastfood', num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2, restaurant_name=None):
    """
    Recommends restaurants based on either:
    - City and cuisine preferences (first logic), or
    - A specific restaurant's name (second logic).
    """
    
    # Ensure user_cuisines is always a list
    if isinstance(user_cuisines, str):
        user_cuisines = [user_cuisines]
    
    # If restaurant_name is provided, use the second logic for recommendations
    if restaurant_name:
        # Filter data for the specific city and cuisine
        filtered_df = dfc[(dfc['city'] == city) & (dfc['cuisines'].str.contains('|'.join(user_cuisines), case=False))].reset_index(drop=True)
        
        # Check if there are enough restaurants after filtering
        if len(filtered_df) < 2:
            print(f"Not enough restaurants in {city} for the cuisine(s) '{', '.join(user_cuisines)}' to provide recommendations.")
            return
        
        # Apply TF-IDF on 'cuisines' for the filtered data
        tfidf = TfidfVectorizer()
        tfidf_matrix = tfidf.fit_transform(filtered_df['cuisines'])
        
        # Check if the restaurant exists in the filtered dataset
        if restaurant_name not in filtered_df['restaurant_name'].values:
            print(f"The restaurant '{restaurant_name}' was not found in {city} for the cuisine(s) '{', '.join(user_cuisines)}'.")
            return
        
        # Find the index of the selected restaurant
        restaurant_idx = filtered_df[filtered_df['restaurant_name'] == restaurant_name].index[0]
        
        # Calculate cosine similarity between the selected restaurant and all others
        cosine_similarities = cosine_similarity(tfidf_matrix[restaurant_idx], tfidf_matrix)
        
        # Get indices of the top 5 most similar restaurants
        similar_indices = cosine_similarities[0].argsort()[-(num_recommendations + 1):][::-1]  # Get top 5 most similar excluding the restaurant itself
        
        # Exclude the first index (which will be the restaurant itself)
        similar_indices = similar_indices[1:]
        
        # Get the names of the recommended restaurants
        recommended_restaurants = filtered_df.iloc[similar_indices]['restaurant_name']
        
        # Print the recommended restaurants
        print(f"\nRecommendations for '{restaurant_name}' in {city}:")
        print(recommended_restaurants.values)
        return

    # If no restaurant_name is provided, use the first logic for recommendations
    else:
        df_city = dfc[dfc['city'] == city]
        df_city['ratings_origin'] = df_city['ratings']
        
        # Scale ratings and distance 
        scaler = MinMaxScaler()
        df_city.loc[:, ['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])

        # Compute TF-IDF for cuisines
        tfidf = TfidfVectorizer()
        cuisine_metric = tfidf.fit_transform(df_city['cuisines'])

        message = ""
        if user_cuisines:
            available_cuisines = df_city['cuisines'].str.lower().unique()
            user_cuisines_lower = [c.lower() for c in user_cuisines]

            # Check if user-provided cuisines exist in the dataset
            matched_cuisines = [c for c in user_cuisines_lower if any(c in cuisine for cuisine in available_cuisines)]

            if not matched_cuisines:  # No matching cuisines found
                return pd.DataFrame(columns=['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'distance_origin']), "No restaurants offering the requested cuisines: {}".format(', '.join(user_cuisines))

            # If the cuisines are present but less popular
            if len(matched_cuisines) < 2:
                message = "Dear user, your requested cuisine(s) are less popular, so the recommendations are based on overall higher ratings, higher cuisines similarity score, or distance."

        # Compute similarity matrices
        rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
        distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
        np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
        cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)

        # Apply user preferences to cuisine similarity
        if user_cuisines:
            user_cuisines_str = ', '.join(user_cuisines)
            user_cuisine_vector = tfidf.transform([user_cuisines_str])
            user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()

            # Boost cuisine similarity for matching restaurants
            cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]

        # Calculate weighted similarity
        weighted_similarity = (cuisines_weight * cuisine_similarity +
                               ratings_weight * rating_similarity +
                               distance_weight * distance_similarity)

        # Create similarity DataFrame
        similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'],
                                     index=df_city['restaurant_name'])

        # Aggregate similarity scores for all restaurants
        aggregated_scores = similarity_df.sum(axis=0)

        # Get the top N recommendations based on aggregated scores
        top_recommendations = aggregated_scores.nlargest(num_recommendations).index.tolist()

        # Create a DataFrame for the top recommendations with specific columns
        top_recommendations_df = df_city[df_city['restaurant_name'].isin(top_recommendations)].copy()

        # Select only the specified columns
        top_recommendations_df = top_recommendations_df[
            ['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']]

        # Add a message column to the recommendations DataFrame
        top_recommendations_df['message'] = message

        return top_recommendations_df, message

# %%
rp_or_get_recommendations2(city='mehsana',user_cuisines=['pizzas'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15600\4189458566.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['ratings_origin'] = df_city['ratings']
# (                 restaurant_name  ratings_origin         address  \
#  22              7 heart pizzeria             4.2         mehsana
#  1467                   hungritos             3.7         mehsana
#  1562          jay ambe fast food             4.3         mehsana
#  1949                london wraps             4.2  radhanpur road
#  4087  zorko brand of food lovers             5.0         mehsana
#
#                                    cuisines  pricing_impute  \
#  22                        pizzas, fastfood            80.0
#  1467   snacks, fastfood, beverages, pizzas           250.0
#  1562           fastfood, pizzas, beverages            40.0
#  1949                      fastfood, pizzas            80.0
#  4087  beverages, pizzas, fastfood, burgers            40.0
#
#                                                  message
#  22    Dear user, your requested cuisine(s) are less ...
#  1467  Dear user, your requested cuisine(s) are less ...
#  1562  Dear user, your requested cuisine(s) are less ...
#  1949  Dear user, your requested cuisine(s) are less ...
#  4087  Dear user, your requested cuisine(s) are less ...  ,
#  'Dear user, your requested cuisine(s) are less popular, so the recommendations are based on overall higher ratings, higher cuisines similarity score, or distance.')

# %%
def rp_or_get_recommendations3(city, user_cuisines='fastfood', num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2, restaurant_name=None):
    """
    Recommends restaurants based on either:
    - City and cuisine preferences (first logic), or
    - A specific restaurant's name (second logic).
    """
    
    # Ensure user_cuisines is always a list
    if isinstance(user_cuisines, str):
        user_cuisines = [user_cuisines]
        
      
    
    # If restaurant_name is provided, use the second logic for recommendations
    if restaurant_name:
        # Filter data for the specific city and cuisine
        filtered_df = dfc[(dfc['city'] == city) & (dfc['cuisines'].str.contains('|'.join(user_cuisines), case=False))].reset_index(drop=True)
        
         
        
        # Check if there are enough restaurants after filtering
        if len(filtered_df) < 2:
            print(f"Not enough restaurants in {city} for the cuisine(s) '{', '.join(user_cuisines)}' to provide recommendations.")
            return
        
        # Apply TF-IDF on 'cuisines' for the filtered data
        tfidf = TfidfVectorizer()
        tfidf_matrix = tfidf.fit_transform(filtered_df['cuisines'])
        
        # Check if the restaurant exists in the filtered dataset
        if restaurant_name not in filtered_df['restaurant_name'].values:
            print(f"The restaurant '{restaurant_name}' was not found in {city} for the cuisine(s) '{', '.join(user_cuisines)}'.")
            return
        
        # Find the index of the selected restaurant
        restaurant_idx = filtered_df[filtered_df['restaurant_name'] == restaurant_name].index[0]
        
        # Calculate cosine similarity between the selected restaurant and all others
        cosine_similarities = cosine_similarity(tfidf_matrix[restaurant_idx], tfidf_matrix)
        
        # Get indices of the top 5 most similar restaurants
        similar_indices = cosine_similarities[0].argsort()[-(num_recommendations + 1):][::-1]  # Get top 5 most similar excluding the restaurant itself
        
        # Exclude the first index (which will be the restaurant itself)
        similar_indices = similar_indices[1:]
        
        # Get the recommended restaurants based on similarity
        recommended_restaurants = filtered_df.iloc[similar_indices]

        # Selecting the specific columns you want
        recommended_restaurants = recommended_restaurants[
            ['restaurant_name', 'ratings', 'address', 'cuisines', 'pricing_impute']]

        # Rename the 'ratings' column to 'ratings_origin' to match your desired output format
        recommended_restaurants.rename(columns={'ratings': 'ratings_origin'}, inplace=True)

        # Print the recommended restaurants
        print(f"\nRecommendations for '{restaurant_name}' in {city}:")
        print(recommended_restaurants)
        return recommended_restaurants

    # If no restaurant_name is provided, use the first logic for recommendations
    else:
        df_city = dfc[dfc['city'] == city]
        df_city['ratings_origin'] = df_city['ratings']
        
        # Scale ratings and distance 
        scaler = MinMaxScaler()
        df_city.loc[:, ['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])

        # Compute TF-IDF for cuisines
        tfidf = TfidfVectorizer()
        cuisine_metric = tfidf.fit_transform(df_city['cuisines'])

        message = ""
        if user_cuisines:
            available_cuisines = df_city['cuisines'].str.lower().unique()
            user_cuisines_lower = [c.lower() for c in user_cuisines]

            # Check if user-provided cuisines exist in the dataset
            matched_cuisines = [c for c in user_cuisines_lower if any(c in cuisine for cuisine in available_cuisines)]

            if not matched_cuisines:  # No matching cuisines found
                return pd.DataFrame(columns=['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']), "No restaurants offering the requested cuisines: {}".format(', '.join(user_cuisines))

            # If the cuisines are present but less popular
            if len(matched_cuisines) < 2:
                message = "Dear user, your requested cuisine(s) are less popular, so the recommendations are based on overall higher ratings, higher cuisines similarity score, or distance."

        # Compute similarity matrices
        rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
        distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
        np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
        cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)

        # Apply user preferences to cuisine similarity
        if user_cuisines:
            user_cuisines_str = ', '.join(user_cuisines)
            user_cuisine_vector = tfidf.transform([user_cuisines_str])
            user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()

            # Boost cuisine similarity for matching restaurants
            cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]

        # Calculate weighted similarity
        weighted_similarity = (cuisines_weight * cuisine_similarity +
                               ratings_weight * rating_similarity +
                               distance_weight * distance_similarity)

        # Create similarity DataFrame
        similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'],
                                     index=df_city['restaurant_name'])

        # Aggregate similarity scores for all restaurants
        aggregated_scores = similarity_df.sum(axis=0)

        # Get the top N recommendations based on aggregated scores
        top_recommendations = aggregated_scores.nlargest(num_recommendations).index.tolist()

        # Create a DataFrame for the top recommendations with specific columns
        top_recommendations_df = df_city[df_city['restaurant_name'].isin(top_recommendations)].copy()

        # Select only the specified columns
        top_recommendations_df = top_recommendations_df[
            ['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']]

        # Add a message column to the recommendations DataFrame
        top_recommendations_df['message'] = message

        return top_recommendations_df, message

# %%
rp_or_get_recommendations3(city='mehsana',user_cuisines=['pizzas'],restaurant_name='jay ambe fast food')
# Out:
# Recommendations for 'jay ambe fast food' in mehsana:
#                restaurant_name  ratings_origin         address  \
# 17                moment mocha             4.1         mehsana
# 10                   hungritos             3.7         mehsana
# 29  zorko brand of food lovers             5.0         mehsana
# 14                london wraps             4.2  radhanpur road
# 0             7 heart pizzeria             4.2         mehsana
#
#                                 cuisines  pricing_impute
# 17   beverages, fastfood, pizzas, snacks           100.0
# 10   snacks, fastfood, beverages, pizzas           250.0
# 29  beverages, pizzas, fastfood, burgers            40.0
# 14                      fastfood, pizzas            80.0
# 0                       pizzas, fastfood            80.0
#                restaurant_name  ratings_origin         address  \
# 17                moment mocha             4.1         mehsana
# 10                   hungritos             3.7         mehsana
# 29  zorko brand of food lovers             5.0         mehsana
# 14                london wraps             4.2  radhanpur road
# 0             7 heart pizzeria             4.2         mehsana
#
#                                 cuisines  pricing_impute
# 17   beverages, fastfood, pizzas, snacks           100.0
# 10   snacks, fastfood, beverages, pizzas           250.0
# 29  beverages, pizzas, fastfood, burgers            40.0
# 14                      fastfood, pizzas            80.0
# 0                       pizzas, fastfood            80.0

# %%
def rp_or_get_recommendations55(city, user_cuisines='fastfood', num_recommendations=5, cuisines_weight=0.5, ratings_weight=0.3, distance_weight=0.2, restaurant_name=None):
    """
    Recommends restaurants based on either:
    - City and cuisine preferences (first logic), or
    - A specific restaurant's name (second logic).
    """
    
    # Ensure user_cuisines is always a list
    if isinstance(user_cuisines, str):
        user_cuisines = [user_cuisines]
    
    # If restaurant_name is provided, use the second logic for recommendations
    if restaurant_name:
        # Filter data for the specific city and cuisine
        filtered_df = dfc[(dfc['city'] == city) & (dfc['cuisines'].str.contains('|'.join(user_cuisines), case=False))].reset_index(drop=True)
        filtered_df['ratings_origin'] = filtered_df['ratings']
        
        # Check if there are enough restaurants after filtering
        if len(filtered_df) < 2:
            return pd.DataFrame(columns=['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']), \
                f"Not enough restaurants in {city} for the cuisine(s) '{', '.join(user_cuisines)}' to provide recommendations."
        
        # Apply TF-IDF on 'cuisines' for the filtered data
        tfidf = TfidfVectorizer()
        tfidf_matrix = tfidf.fit_transform(filtered_df['cuisines'])
        
        # Check if the restaurant exists in the filtered dataset
        if restaurant_name not in filtered_df['restaurant_name'].values:
            return pd.DataFrame(columns=['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']), \
                f"The restaurant '{restaurant_name}' was not found in {city} for the cuisine(s) '{', '.join(user_cuisines)}'."
        
        # Find the index of the selected restaurant
        restaurant_idx = filtered_df[filtered_df['restaurant_name'] == restaurant_name].index[0]
        
        # Calculate cosine similarity between the selected restaurant and all others
        cosine_similarities = cosine_similarity(tfidf_matrix[restaurant_idx], tfidf_matrix)
        
        # Get indices of the top 5 most similar restaurants
        similar_indices = cosine_similarities[0].argsort()[-(num_recommendations + 1):][::-1]  # Get top 5 most similar excluding the restaurant itself
        
        # Exclude the first index (which will be the restaurant itself)
        similar_indices = similar_indices[1:]
        
        # Get the recommended restaurants
        recommended_restaurants = filtered_df.iloc[similar_indices][['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']]
        
        # Return the DataFrame with recommendations
        return recommended_restaurants, None  # No message needed as it is included in the result
    
    # If no restaurant_name is provided, use the first logic for recommendations
    else:
        # Original logic for recommendations when no restaurant_name is provided
        df_city = dfc[dfc['city'] == city].copy()
        df_city.loc[:, 'ratings_origin'] = df_city['ratings']
        # Scale ratings and distance 
        scaler = MinMaxScaler()
        df_city.loc[:, ['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])

        # Compute TF-IDF for cuisines
        tfidf = TfidfVectorizer()
        cuisine_metric = tfidf.fit_transform(df_city['cuisines'])

        message = ""
        if user_cuisines:
            available_cuisines = df_city['cuisines'].str.lower().unique()
            user_cuisines_lower = [c.lower() for c in user_cuisines]

            # Check if user-provided cuisines exist in the dataset
            matched_cuisines = [c for c in user_cuisines_lower if any(c in cuisine for cuisine in available_cuisines)]

            if not matched_cuisines:  # No matching cuisines found
                return pd.DataFrame(columns=['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'distance_origin']), "No restaurants offering the requested cuisines: {}".format(', '.join(user_cuisines))

            # If the cuisines are present but less popular
            if len(matched_cuisines) < 1:
                message = "Dear user, your requested cuisine(s) are less popular, so the recommendations are based on overall higher ratings, higher cuisines similarity score, or distance."

        # Compute similarity matrices
        rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
        distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
        np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
        cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)

        # Apply user preferences to cuisine similarity
        if user_cuisines:
            user_cuisines_str = ', '.join(user_cuisines)
            user_cuisine_vector = tfidf.transform([user_cuisines_str])
            user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()

            # Boost cuisine similarity for matching restaurants
            cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]

        # Calculate weighted similarity
        weighted_similarity = (cuisines_weight * cuisine_similarity +
                               ratings_weight * rating_similarity +
                               distance_weight * distance_similarity)

        # Create similarity DataFrame
        similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'],
                                     index=df_city['restaurant_name'])

        # Aggregate similarity scores for all restaurants
        aggregated_scores = similarity_df.sum(axis=0)

        # Get the top N recommendations based on aggregated scores
        top_recommendations = aggregated_scores.nlargest(num_recommendations).index.tolist()

        # Create a DataFrame for the top recommendations with specific columns
        top_recommendations_df = df_city[df_city['restaurant_name'].isin(top_recommendations)].copy()

        # Select only the specified columns
        top_recommendations_df = top_recommendations_df[
            ['restaurant_name', 'ratings_origin', 'address', 'cuisines', 'pricing_impute']]

        # Add a message column to the recommendations DataFrame
        top_recommendations_df['message'] = message

        return top_recommendations_df, message

# %%
rp_or_get_recommendations55(city='mehsana',user_cuisines=['chinese'],restaurant_name='food adda')
# Out:
# (          restaurant_name  ratings_origin                      address  \
#  7     jay bhavani vadapav             4.2                      mehsana
#  5             hotel tulsi             4.3                      mehsana
#  4         hotel highlaned             4.4                      mehsana
#  18   shree sai restaurant             4.4  tirupati shahibaug township
#  19  the foodies fast food             3.8            geb visnagar road
#
#                                               cuisines  pricing_impute
#  7                                   fastfood, chinese            40.0
#  5   southindian, chinese, fastfood, pizzas, beverages            80.0
#  4   chinese, punjabi, beverages, snacks, pizzas, f...            40.0
#  18                         chinese, punjabi, fastfood           150.0
#  19                 chinese, snacks, beverages, pizzas            80.0  ,
#  None)

# %%
def ex(city, user_cuisines=None, num_recommendations=5, cuisines_weight=0.6, ratings_weight=0.4):
    
    
    df_city = dfc[dfc['city'] == city]
    
    # Scale ratings and distance
    scaler = MinMaxScaler()
    #df_city.loc[:,['ratings', 'distance']] = scaler.fit_transform(df_city[['ratings', 'distance']])
    df_city.loc[:,['ratings']] = scaler.fit_transform(df_city[['ratings']])
    
    
    # Compute TF-IDF for cuisines
    tfidf = TfidfVectorizer()
    cuisine_metric = tfidf.fit_transform(df_city['cuisines'])
    
     # If user_cuisines are provided, ensure they exist in the dataset
    if user_cuisines:
        available_cuisines = df_city['cuisines'].str.lower().unique()
        user_cuisines_lower = [c.lower() for c in user_cuisines]
        
        # Check if any of the requested cuisines exist in the dataset
        if not any(cuisine in ', '.join(available_cuisines) for cuisine in user_cuisines_lower):
            return f"No restaurants offering the requested cuisines: {', '.join(user_cuisines)}."
        
    
    # Compute similarity matrices
    rating_similarity = cosine_similarity(df_city[['ratings']], df_city[['ratings']])
    #distance_similarity = cosine_similarity(df_city[['distance']], df_city[['distance']])
    #np.fill_diagonal(distance_similarity, 1.0)  # Adjust distance similarity for self-comparisons
    cuisine_similarity = cosine_similarity(cuisine_metric, cuisine_metric)
    
    # Apply user preferences to cuisine similarity
    if user_cuisines:
        user_cuisines_str = ', '.join(user_cuisines)
        user_cuisine_vector = tfidf.transform([user_cuisines_str])
        user_cuisine_similarity = cosine_similarity(cuisine_metric, user_cuisine_vector).flatten()
        
        # Boost cuisine similarity for matching restaurants
        cuisine_similarity *= user_cuisine_similarity[:, np.newaxis]
    
    # Calculate weighted similarity
    weighted_similarity = (cuisines_weight * cuisine_similarity +
                           ratings_weight * rating_similarity)
    
    # Create similarity DataFrame
    similarity_df = pd.DataFrame(weighted_similarity, columns=df_city['restaurant_name'], index=df_city['restaurant_name'])
    
    # Aggregate similarity scores for all restaurants
    aggregated_scores = similarity_df.sum(axis=0)
    
    # Get the top N recommendations based on aggregated scores
    top_recommendations_overall = aggregated_scores.nlargest(num_recommendations).index.tolist()
    
    
    return top_recommendations_overall


# r(city='mehsana', user_cuisines=['chinese'])

# %%
ex(city='mehsana',user_cuisines=['snacks'])
# Out:
# ['hungritos',
#  'moment mocha',
#  'the foodies fast food',
#  'murli food home-radhanpur road',
#  'hotel highlaned']

# %%
dfc[(dfc['city']=='mehsana') & (dfc['restaurant_name']=="hotel highlaned")]
# Out:
#       restaurant_name  ratings  address  distance     city  \
# 1428  hotel highlaned      4.4  mehsana      28.8  mehsana
#
#                                                cuisines  pricing_impute
# 1428  chinese, punjabi, beverages, snacks, pizzas, f...            40.0
